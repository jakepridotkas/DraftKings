# %% [markdown]
# ### DK Salaries Optimizer

# %%
import pandas as pd
import numpy as np
from pulp import *

# %%
dk_data = pd.read_csv("data/dksalaries_mlb.csv")

# Get the fields that are useful
dk_data = dk_data[['Name', 'Roster Position', 'Salary', 'TeamAbbrev', 'AvgPointsPerGame']]

dk_data.head()
# Out:
#                 Name Roster Position  Salary TeamAbbrev  AvgPointsPerGame
# 0         Yu Darvish               P   11000        CHC             26.25
# 1       Shane Bieber               P   11000        CLE             33.76
# 2       Max Scherzer               P   11000        WAS             20.84
# 3         Chris Sale               P   10800        BOS              0.00
# 4  Eduardo Rodriguez               P   10500        BOS              0.00

# %%
injured_players = ["Darren O'Day", "Travis d'Arnaud", "Ryan O'Hearn", "Peter O'Brien", "Brian O'Grady",
                  "Ke'Bryan Hayes", "Logan O'Hoppe"]

# %%
dk_data = dk_data[~dk_data['Name'].isin(injured_players)]

# %%
# Roster Positions for NBA 
mlb_roster_positions = ['P', 'C', '1B', '2B', '3B', 'SS', 'OF']

SALARY_CAP = 50000
MAX_PLAYERS = 10


def make_vars(name, position, roster_position):
    if position in roster_position:
        return LpVariable(name + '_' + position,lowBound=0, cat='Binary')
    return 0

for position in mlb_roster_positions:
    dk_data[position] = dk_data.apply(lambda x: make_vars(x['Name'],position, x['Roster Position']),axis=1)

    #[1 if position in x else 0 for x in dk_data['Roster Position']]

# %%
prob = LpProblem("OptimizeDK",LpMaximize)

# %%
names = dk_data['Name']
salaries = dk_data['Salary']
projected_points = dk_data['AvgPointsPerGame']

# %%
dk_data.tail(30)
# Out:
#                    Name Roster Position  Salary TeamAbbrev  AvgPointsPerGame  \
# 1220        Nick Ciuffo               C    2000        TEX              0.00
# 1221           Sam Huff               C    2000        TEX              0.00
# 1222      Adolis Garcia              OF    2000        TEX              0.67
# 1223      Yadiel Rivera           2B/OF    2000        TEX              1.67
# 1224    Sherten Apostel              3B    2000        TEX              0.00
# 1225      Rob Refsnyder           1B/OF    2000        TEX              2.40
# 1226     Scott Heineman              OF    2000        TEX              3.71
# 1227      Ronald Guzman              1B    2000        TEX              9.00
# 1228      Scott Kingery           2B/OF    2000        PHI              2.91
# 1229      Victor Robles              OF    2000        WAS              5.41
# 1230       Adam Haseley              OF    2000        PHI              2.47
# 1231       Andrew Knapp               C    2000        PHI              4.58
# 1232      Mikie Mahtook              OF    2000        PHI              0.00
# 1233       Tres Barrera               C    2000        WAS              0.00
# 1234       Jakson Reetz               C    2000        WAS              0.00
# 1235     Rafael Marchan               C    2000        PHI              0.00
# 1236     Brandon Snyder              3B    2000        WAS              0.00
# 1237   Andrew Stevenson              OF    2000        WAS              3.00
# 1238  Michael A. Taylor              OF    2000        WAS              4.28
# 1239     Adrian Sanchez              2B    2000        WAS              0.00
# 1240        Wilmer Difo           2B/SS    2000        WAS              0.56
# 1241  Arquimedes Gamboa              SS    2000        PHI              0.00
# 1243     Henri Lartigue               C    2000        PHI              0.00
# 1244          Jake Noll              2B    2000        WAS              0.00
# 1245   Yadiel Hernandez              OF    2000        WAS              0.00
# 1246         Brock Holt           3B/OF    2000        WAS              1.28
# 1247   Emilio Bonifacio              OF    2000        WAS              0.67
# 1248    Ronald Torreyes              SS    2000        PHI              0.00
# 1249       Nick Martini              OF    2000        PHI              0.00
# 1250        Neil Walker           1B/2B    2000        PHI              2.36
#
#       P                 C                1B                 2B  \
# 1220  0     Nick_Ciuffo_C                 0                  0
# 1221  0        Sam_Huff_C                 0                  0
# 1222  0                 0                 0                  0
# 1223  0                 0                 0   Yadiel_Rivera_2B
# 1224  0                 0                 0                  0
# 1225  0                 0  Rob_Refsnyder_1B                  0
# 1226  0                 0                 0                  0
# 1227  0                 0  Ronald_Guzman_1B                  0
# 1228  0                 0                 0   Scott_Kingery_2B
# 1229  0                 0                 0                  0
# 1230  0                 0                 0                  0
# 1231  0    Andrew_Knapp_C                 0                  0
# 1232  0                 0                 0                  0
# 1233  0    Tres_Barrera_C                 0                  0
# 1234  0    Jakson_Reetz_C                 0                  0
# 1235  0  Rafael_Marchan_C                 0                  0
# 1236  0                 0                 0                  0
# 1237  0                 0                 0                  0
# 1238  0                 0                 0                  0
# 1239  0                 0                 0  Adrian_Sanchez_2B
# 1240  0                 0                 0     Wilmer_Difo_2B
# 1241  0                 0                 0                  0
# 1243  0  Henri_Lartigue_C                 0                  0
# 1244  0                 0                 0       Jake_Noll_2B
# 1245  0                 0                 0                  0
# 1246  0                 0                 0                  0
# 1247  0                 0                 0                  0
# 1248  0                 0                 0                  0
# 1249  0                 0                 0                  0
# 1250  0                 0    Neil_Walker_1B     Neil_Walker_2B
#
#                       3B                    SS                    OF
# 1220                   0                     0                     0
# 1221                   0                     0                     0
# 1222                   0                     0      Adolis_Garcia_OF
# 1223                   0                     0      Yadiel_Rivera_OF
# 1224  Sherten_Apostel_3B                     0                     0
# 1225                   0                     0      Rob_Refsnyder_OF
# 1226                   0                     0     Scott_Heineman_OF
# 1227                   0                     0                     0
# 1228                   0                     0      Scott_Kingery_OF
# 1229                   0                     0      Victor_Robles_OF
# 1230                   0                     0       Adam_Haseley_OF
# 1231                   0                     0                     0
# 1232                   0                     0      Mikie_Mahtook_OF
# 1233                   0                     0                     0
# 1234                   0                     0                     0
# 1235                   0                     0                     0
# 1236   Brandon_Snyder_3B                     0                     0
# 1237                   0                     0   Andrew_Stevenson_OF
# 1238                   0                     0  Michael_A._Taylor_OF
# 1239                   0                     0                     0
# 1240                   0        Wilmer_Difo_SS                     0
# 1241                   0  Arquimedes_Gamboa_SS                     0
# 1243                   0                     0                     0
# 1244                   0                     0                     0
# 1245                   0                     0   Yadiel_Hernandez_OF
# 1246       Brock_Holt_3B                     0         Brock_Holt_OF
# 1247                   0                     0   Emilio_Bonifacio_OF
# 1248                   0    Ronald_Torreyes_SS                     0
# 1249                   0                     0       Nick_Martini_OF
# 1250                   0                     0                     0

# %%
print(dk_data['Name'])
# Out:
# 0              Yu Darvish
# 1            Shane Bieber
# 2            Max Scherzer
# 3              Chris Sale
# 4       Eduardo Rodriguez
# 5           Lucas Giolito
# 6              Aaron Nola
# 7         Carlos Carrasco
# 8          Marcus Stroman
# 9        Mike Foltynewicz
# 10           Zack Wheeler
# 11         Walker Buehler
# 12        Clayton Kershaw
# 13           Jacob deGrom
# 14           Corey Kluber
# 15         Patrick Corbin
# 16            Gerrit Cole
# 17      Stephen Strasburg
# 18           Zack Greinke
# 19            Julio Urias
# 20             Zac Gallen
# 21            Kenta Maeda
# 22            Mike Soroka
# 23        Cristian Javier
# 24             Jon Lester
# 25           Aaron Civale
# 26            Blake Snell
# 27         Kyle Hendricks
# 28              Max Fried
# 29             Lance Lynn
#               ...
# 1220          Nick Ciuffo
# 1221             Sam Huff
# 1222        Adolis Garcia
# 1223        Yadiel Rivera
# 1224      Sherten Apostel
# 1225        Rob Refsnyder
# 1226       Scott Heineman
# 1227        Ronald Guzman
# 1228        Scott Kingery
# 1229        Victor Robles
# 1230         Adam Haseley
# 1231         Andrew Knapp
# 1232        Mikie Mahtook
# 1233         Tres Barrera
# 1234         Jakson Reetz
# 1235       Rafael Marchan
# 1236       Brandon Snyder
# 1237     Andrew Stevenson
# 1238    Michael A. Taylor
# 1239       Adrian Sanchez
# 1240          Wilmer Difo
# 1241    Arquimedes Gamboa
# 1243       Henri Lartigue
# 1244            Jake Noll
# 1245     Yadiel Hernandez
# 1246           Brock Holt
# 1247     Emilio Bonifacio
# 1248      Ronald Torreyes
# 1249         Nick Martini
# 1250          Neil Walker
# Name: Name, Length: 1243, dtype: object

# %%
# The objective function is added to 'prob' first
# OBJ FUNCTION
prob += lpSum([dk_data[i] * projected_points for i in mlb_roster_positions]), 'Projected Points'

# %%
# CONSTRAINTS

# Stay under salary cap
prob += lpSum(salaries * dk_data[i] for i in mlb_roster_positions) <= SALARY_CAP

# Stay under Num Players
prob += lpSum(dk_data[i] for i in mlb_roster_positions) <= MAX_PLAYERS

# Select one of each position
prob += lpSum([dk_data['P']]) >= 2
prob += lpSum([dk_data['C']]) >= 1
prob += lpSum([dk_data['1B']]) >= 1
prob += lpSum([dk_data['2B']]) >= 1
prob += lpSum([dk_data['3B']]) >= 1
prob += lpSum([dk_data['SS']]) >= 1
prob += lpSum([dk_data['OF']]) >= 3


# Don't use same player twice
for index, row in dk_data.iterrows():
    prob += lpSum(row[i] for i in mlb_roster_positions) <= 1

# %%
prob
# Out:
# OptimizeDK:
# MAXIMIZE
# 7.06*AJ_Pollock_OF + 5.39*Aaron_Bummer_P + 19.34*Aaron_Civale_P + 6.31*Aaron_Hicks_OF + 11.44*Aaron_Judge_OF + 3.34*Aaron_Loup_P + 24.2*Aaron_Nola_P + 5.66*Aaron_Slegers_P + 4.43*Abraham_Toro_3B + 4.6*Adalberto_Mondesi_SS + 2.02*Adam_Cimber_P + 5.47*Adam_Duvall_OF + 7.28*Adam_Eaton_OF + 5.0*Adam_Engel_OF + 5.68*Adam_Frazier_2B + 5.68*Adam_Frazier_OF + 2.47*Adam_Haseley_OF + 4.5*Adam_Kolarek_P + 1.95*Adam_Morgan_P + 2.69*Adam_Ottavino_P + 4.88*Adam_Plutko_P + 13.25*Adbert_Alzolay_P + 1.67*Adeiny_Hechavarria_2B + 1.67*Adeiny_Hechavarria_SS + 0.67*Adolis_Garcia_OF + 10.91*Adrian_Houser_P + -0.6*Albert_Abreu_P + 1.25*Albert_Almora_Jr._OF + 6.6*Alec_Bohm_3B + 10.21*Alec_Mills_P + 2.5*Aledmys_Diaz_1B + 2.5*Aledmys_Diaz_OF + 3.89*Alex_Avila_C + 8.46*Alex_Bregman_3B + 1.75*Alex_Claudio_P + 9.81*Alex_Cobb_P + 3.46*Alex_Colome_P + 5.4*Alex_Dickerson_OF + 4.9*Alex_Gordon_OF + 1.6*Alex_Jackson_C + 8.39*Alex_Verdugo_OF + 5.15*Alex_Wood_P + 6.3*Alex_Young_P + 0.75*Ali_Sanchez_C + 4.86*Amed_Rosario_SS + 8.67*Anderson_Tejeda_2B + 4.11*Andre_Scrubb_P + 4.52*Andres_Gimenez_2B + 4.52*Andres_Gimenez_SS + 3.79*Andrew_Benintendi_OF + 1.74*Andrew_Chafin_P + 1.75*Andrew_Kittredge_P + 4.58*Andrew_Knapp_C + 8.11*Andrew_McCutchen_OF + 3.0*Andrew_Stevenson_OF + 0.7*Andrew_Suarez_P + 2.37*Andrew_Velazquez_SS + 5.0*Andy_Young_3B + -0.87*Angel_Perdomo_P + 6.72*Anibal_Sanchez_P + 0.39*Anthony_Banda_P + -0.95*Anthony_Castro_P + 7.74*Anthony_Rizzo_1B + 9.97*Anthony_Santander_OF + 14.79*Antonio_Senzatela_P + 1.17*Aroldis_Chapman_P + 7.27*Asdrubal_Cabrera_1B + 7.27*Asdrubal_Cabrera_3B + 9.74*Asher_Wojciechowski_P + -3.1*Ashton_Goudeau_P + 6.0*Austin_Barnes_C + 2.69*Austin_Brice_P + 5.21*Austin_Hays_OF + 3.34*Austin_Hedges_C + 7.86*Austin_Meadows_OF + 7.0*Austin_Riley_3B + 6.5*Austin_Romine_C + 8.84*Austin_Slater_OF + 3.48*Austin_Voth_P + 5.77*Avisail_Garcia_OF + 1.75*Beau_Burrows_P + 1.86*Beau_Taylor_C + 5.11*Ben_Gamel_OF + 4.22*Ben_Heller_P + 1.88*Billy_Hamilton_OF + 6.59*Blake_Parker_P + 15.9*Blake_Snell_P + 3.53*Blake_Taylor_P + 3.84*Blake_Treinen_P + 9.5*Bobby_Dalbec_1B + 9.5*Bobby_Dalbec_3B + -0.38*Bobby_Wahl_P + 2.85*Brad_Brach_P + 2.9*Brad_Hand_P + 18.08*Brad_Keller_P + 1.05*Brad_Wieck_P + 3.55*Bradley_Zimmer_OF + 10.83*Brady_Singer_P + 2.9*Brandon_Bailey_P + 7.43*Brandon_Belt_1B + 6.9*Brandon_Bielak_P + 5.64*Brandon_Crawford_SS + 9.91*Brandon_Lowe_2B + 9.91*Brandon_Lowe_OF + 7.79*Brandon_Nimmo_OF + 3.55*Brandon_Waddell_P + 16.64*Brandon_Woodruff_P + 2.34*Brandon_Workman_P + 2.0*Brendan_Rodgers_2B + 2.0*Brendan_Rodgers_SS + 6.12*Brent_Suter_P + 10.07*Brett_Anderson_P + 4.96*Brett_Gardner_OF + 2.46*Brett_Martin_P + 1.28*Brock_Holt_3B + 1.28*Brock_Holt_OF + 0.2*Brooks_Kriske_P + 2.61*Brooks_Raley_P + 2.06*Brusdar_Graterol_P + 1.38*Bryan_Abreu_P + 2.34*Bryan_Garcia_P + 2.54*Bryan_Holaday_C + 5.47*Bryan_Reynolds_OF + 10.52*Bryce_Harper_OF + 0.15*Bryse_Wilson_P + 1.83*Bubba_Starling_OF + 1.76*Buck_Farmer_P + 6.33*Byron_Buxton_OF + 8.62*C.J._Cron_1B + 5.8*Cal_Quantrill_P + 2.51*Caleb_Baragar_P + 4.59*Caleb_Ferguson_P + 6.55*Caleb_Smith_P + 4.64*Caleb_Thielbar_P + 4.4*Cam_Gallagher_C + 2.94*Cam_Hill_P + 4.79*Cameron_Maybin_OF + 17.17*Carlos_Carrasco_P + 6.85*Carlos_Correa_SS + 2.66*Carlos_Estevez_P + 2.38*Carlos_Rodon_P + 7.17*Carlos_Santana_1B + 1.69*Carson_Fulmer_P + 3.52*Carson_Kelly_C + 4.82*Carter_Kieboom_3B + 6.93*Casey_Mize_P + 1.74*Casey_Sadler_P + 3.83*Cedric_Mullins_OF + 7.26*Cesar_Hernandez_2B + 12.42*Cesar_Valdez_P + 6.34*Chad_Green_P + 11.68*Chad_Kuhl_P + 2.32*Chad_Sobotka_P + 4.29*Chadwick_Tromp_C + -2.65*Chance_Adams_P + 6.26*Chance_Sisco_C + 9.06*Charlie_Blackmon_OF + 1.38*Charlie_Culberson_2B + 1.38*Charlie_Culberson_OF + 9.82*Charlie_Morton_P + 7.84*Chasen_Shreve_P + 3.26*Chaz_Roe_P + 6.88*Chi_Chi_Gonzalez_P + 2.53*Chris_Davis_1B + 1.75*Chris_Devenski_P + 3.47*Chris_Martin_P + 4.0*Chris_Mazza_P + 5.18*Chris_Owings_2B + 5.18*Chris_Owings_OF + 2.1*Chris_Rusin_P + 3.82*Chris_Stratton_P + 6.0*Chris_Taylor_OF + 6.0*Chris_Taylor_SS + 6.1*Christian_Va ...
# SUBJECT TO
# _C1: 3800 AJ_Pollock_OF + 4000 Aaron_Barrett_P + 2200 Aaron_Bracho_SS
#  + 4000 Aaron_Bummer_P + 9400 Aaron_Civale_P + 3600 Aaron_Hicks_OF
#  + 5600 Aaron_Judge_OF + 4000 Aaron_Loup_P + 10400 Aaron_Nola_P
#  + 4000 Aaron_Shortridge_P + 4000 Aaron_Slegers_P + 2800 Abiatal_Avelino_SS
#  + 2200 Abraham_Toro_3B + 4000 Adalberto_Mejia_P + 2900 Adalberto_Mondesi_SS
#  + 4000 Adam_Cimber_P + 3100 Adam_Duvall_OF + 3500 Adam_Eaton_OF
#  + 2000 Adam_Engel_OF + 3200 Adam_Frazier_2B + 3200 Adam_Frazier_OF
#  + 2000 Adam_Haseley_OF + 4000 Adam_Kolarek_P + 4000 Adam_Morgan_P
#  + 4200 Adam_Ottavino_P + 5900 Adam_Plutko_P + 6500 Adbert_Alzolay_P
#  + 4000 Addison_Russ_P + 3200 Adeiny_Hechavarria_2B
#  + 3200 Adeiny_Hechavarria_SS + 2700 Adley_Rutschman_C + 2000 Adolis_Garcia_OF
#  + 7600 Adonis_Medina_P + 4000 Adonis_Rosa_P + 8500 Adrian_Houser_P
#  + 2000 Adrian_Sanchez_2B + 2000 Alan_Trejo_SS + 4000 Albert_Abreu_P
#  + 2000 Albert_Almora_Jr._OF + 3200 Alec_Bohm_3B + 7800 Alec_Mills_P
#  + 2100 Aledmys_Diaz_1B + 2100 Aledmys_Diaz_OF + 2000 Alek_Thomas_OF
#  + 2900 Alex_Avila_C + 5100 Alex_Bregman_3B + 4000 Alex_Claudio_P
#  + 7800 Alex_Cobb_P + 4000 Alex_Colome_P + 2100 Alex_De_Goti_2B
#  + 2100 Alex_De_Goti_SS + 3600 Alex_Dickerson_OF + 4000 Alex_Faedo_P
#  + 2100 Alex_Gordon_OF + 3000 Alex_Jackson_C + 2600 Alex_Kirilloff_1B
#  + 2600 Alex_Kirilloff_OF + 4000 Alex_McRae_P + 4000 Alex_Speas_P
#  + 4300 Alex_Verdugo_OF + 7600 Alex_Wood_P + 7300 Alex_Young_P
#  + 2600 Alexander_Canario_OF + 4000 Alexander_Guillen_P
#  + 4000 Alexander_Vizcaino_P + 3000 Ali_Sanchez_C + 2100 Allan_de_San_Miguel_C
#  + 3000 Amed_Rosario_SS + 2200 Anderson_Tejeda_2B + 4000 Andre_Jackson_P
#  + 4000 Andre_Scrubb_P + 2800 Andres_Gimenez_2B + 2800 Andres_Gimenez_SS
#  + 3500 Andrew_Benintendi_OF + 4000 Andrew_Chafin_P + 4000 Andrew_Kittredge_P
#  + 2000 Andrew_Knapp_C + 4000 Andrew_McCutchen_OF + 2000 Andrew_Stevenson_OF
#  + 7400 Andrew_Suarez_P + 2000 Andrew_Vaughn_1B + 3100 Andrew_Velazquez_SS
#  + 2200 Andy_Ibanez_2B + 2500 Andy_Young_3B + 4000 Angel_Perdomo_P
#  + 7100 Anibal_Sanchez_P + 5200 Anthony_Banda_P + 4000 Anthony_Castro_P
#  + 2000 Anthony_Garcia_OF + 5100 Anthony_Rizzo_1B + 5200 Anthony_Santander_OF
#  + 4000 Anthony_Swarzak_P + 4000 Antoine_Kelly_P + 4000 Antonio_Santos_P
#  + 6700 Antonio_Senzatela_P + 2600 Aramis_Garcia_1B + 2600 Aramis_Garcia_C
#  + 4000 Aroldis_Chapman_P + 2000 Arquimedes_Gamboa_SS + 4000 Artie_Lewicki_P
#  + 4700 Asdrubal_Cabrera_1B + 4700 Asdrubal_Cabrera_3B
#  + 5500 Asher_Wojciechowski_P + 4000 Ashton_Goudeau_P + 4000 Austen_Williams_P
#  + 2900 Austin_Barnes_C + 4800 Austin_Brice_P + 4000 Austin_Cox_P
#  + 3300 Austin_Hays_OF + 2000 Austin_Hedges_C + 4800 Austin_Meadows_OF
#  + 4000 Austin_Pruitt_P + 3400 Austin_Riley_3B + 3500 Austin_Romine_C
#  + 4100 Austin_Slater_OF + 6800 Austin_Voth_P + 2900 Austin_Wynns_C
#  + 3300 Avisail_Garcia_OF + 4000 Beau_Burrows_P + 2100 Beau_Taylor_C
#  + 4000 Ben_Bowden_P + 4000 Ben_Braymer_P + 2600 Ben_Gamel_OF
#  + 4000 Ben_Heller_P + 4000 Bennett_Sousa_P + 4000 Bernardo_Flores_Jr._P
#  + 3000 Billy_Hamilton_OF + 4000 Blake_Cederlind_P + 4300 Blake_Parker_P
#  + 2000 Blake_Rutherford_OF + 9200 Blake_Snell_P + 2700 Blake_Swihart_C
#  + 2700 Blake_Swihart_OF + 4000 Blake_Taylor_P + 4000 Blake_Treinen_P
#  + 4000 Blake_Walston_P + 2200 Bo_Naylor_C + 5700 Bo_Takahashi_P
#  + 2500 Bobby_Bradley_1B + 2000 Bobby_Dalbec_1B + 2000 Bobby_Dalbec_3B
#  + 4000 Bobby_Miller_P + 4000 Bobby_Wahl_P + 2100 Bobby_Witt_Jr._SS
#  + 4000 Brad_Brach_P + 4000 Brad_Hand_P + 6900 Brad_Keller_P
#  + 4000 Brad_Peacock_P + 6500 Brad_Wieck_P + 2600 Braden_Shewmake_SS
#  + 2100 Bradley_Zimmer_OF + 2800 Brady_Policelli_C + 6800 Brady_Singer_P
#  + 4000 Braeden_Ogle_P + 6500 Brailyn_Marquez_P + 6500 Branden_Kline_P
#  + 4000 Brandon_Bailey_P + 4200 Brandon_Belt_1B + 8300 Brandon_Bielak_P
#  + 3900 Brandon_Crawford_SS + 3900 Brandon_Dixon_1B + 3900 Brandon_Dixon_OF
#  + 5500 Brandon_Lowe_2B + 5500 Brandon_Lowe_OF + 4400 Brandon_Nimmo_OF
#  + 2000 Brandon_Snyder_3B + 4000 Brandon_Waddell_P + 8200 Brandon_Woodruff_P
#  + 4000 Brandon_Workman_P + 4000 Brendan_McKay_P + 2800 Brendan_Rodgers_2B
#  + 2800 Brendan_Rodgers_SS + 2000 Brennen_Davis_OF
#  + 4000 Brent_Honeywell_Jr._P + 2600 Brent_Rooker_OF + 8300 Brent_Suter_P
#  + 2100 Bret_Boswell_2B + 2100 Bret_Boswell_3B + 6400 Brett_Anderson_P
#  + 4000 Brett_Conine_P + 3000 Brett_Gardner_OF + 6700 Brett_Martin_P
#  + 4000 Brett_de_Geus_P + 5700 Brian_Johnson_P + 2200 Brice_Turang_SS
#  + 7300 Brock_Burke_P + 2000 Brock_Holt_3B + 2000 Brock_Holt_OF
#  + 4000 Brooks_Kriske_P + 4000 Brooks_Raley_P + 4000 Brusdar_Graterol_P
#  + 4000 Bryan_Abreu_P + 4000 Bryan_Garcia_P + 2900 Bryan_Holaday_C
#  + 3100 Bryan_Reynolds_OF + 6000 Bryce_Harper_OF + 4000 Bryce_Jarvis_P
#  + 6700 Bryse_Wilson_P + 2100 Bubba_Starling_OF + 5500 Buck_Farmer_P
#  + 3600 Byron_Buxton_OF + 2000 C.J._Chatham_SS + 4500 C.J._Cron_1B
#  + 4000 Cade_Cavalli_P + 6300 Cal_Quantrill_P + 4000 Caleb_Baragar_P
#  + 4700 Caleb_Ferguson_P + 2600 Caleb_Hamilton_C + 4000 Caleb_Simpson_P
#  + 6200 Caleb_Smith_P + 4000 Caleb_Thielbar_P + 2100 Cam_Gallagher_C
#  + 4000 Cam_Hill_P + 2900 Cameron_Maybin_OF + 4000 Camilo_Doval_P
#  + 10300 Carlos_Carrasco_P + 4700 Carlos_Correa_SS + 4000 Carlos_Estevez_P
#  + 4000 Carlos_Hernandez_P + 4000 Carlos_Navas_P + 4000 Carlos_Rodon_P
#  + 4100 Carlos_Santana_1B + 4000 Carson_Fulmer_P + 2400 Carson_Kelly_C
#  + 2000 Carson_Taylor_C + 2400 Carter_Kieboom_3B + 5800 Casey_Mize_P
#  + 6500 Casey_Sadler_P + 3100 Cedric_Mullins_OF + 4200 Cesar_Hernandez_2B
#  + 2000 Cesar_Puello_OF + 4000 Cesar_Valdez_P + 4700 Chad_Green_P
#  + 7700 Chad_Kuhl_P + 6500 Chad_Sobotka_P + 2800 Chadwick_Tromp_C
#  + 4000 Chance_Adams_P + 4500 Chance_Sisco_C + 6500 Chandler_Shepherd_P
#  + 5900 Charlie_Blackmon_OF + 2100 Charlie_Culberson_2B
#  + 2100 Charlie_Culberson_OF + 9100 Charlie_Morton_P + 2100 Chas_McCormick_OF
#  + 4000 Chasen_Shreve_P + 4000 Chaz_Roe_P + 2600 Cheslor_Cuthbert_1B
#  + 2600 Cheslor_Cuthbert_3B + 6300 Chi_Chi_Gonzalez_P + 4000 Chris_Archer_P
#  + 3100 Chris_Davis_1B + 4000 Chris_Devenski_P + 2100 Chris_Herrmann_C
#  + 2300 Chris_Iannetta_C + 6500 Chris_Martin_P + 5000 Chris_Mazza_P
#  + 3200 Chris_Owings_2B + 3200 Chris_Owings_OF + 2000 Chris_Rabago_C
#  + 6500 Chris_Rusin_P + 10800 Chris_Sale_P + 2500 Chris_Shaw_1B
#  + 2500 Chris_Shaw_OF + 6300 Chris_Stratton_P + 4200 Chris_Taylor_OF
#  + 4200 Chris_Taylor_SS + 2000 Christian_Kelley_C + 4300 Christian_Vazquez_C
#  + 4200 Christian_Walker_1B + 5100 Christian_Yelich_OF
#  + 2700 Christin_Stewart_OF + 2000 Christopher_Morel_3B + 4000 Cionel_Perez_P
#  + 4000 Clarke_Schmidt_P + 4000 Clay_Holmes_P + 4000 Clayton_Andrews_P
#  + 4000 Clayton_Beeter_P + 10200 Clayton_Kershaw_P + 4000 Clint_Frazier_OF
#  + 4000 Codi_Heuer_P + 4000 Cody_Allen_P + 5400 Cody_Bellinger_1B
#  + 5400 Cody_Bellinger_OF + 4000 Cody_Bolton_P + 6500 Cody_Carroll_P
#  + 4000 Cody_Ponce_P + 4000 Cody_Reed_P + 4000 Cody_Stashak_P
#  + 2000 Cody_Thomas_OF + 8900 Cole_Hamels_P + 5600 Cole_Irvin_P
#  + 6500 Cole_Sulser_P + 2500 Cole_Tucker_OF + 3800 Colin_Moran_1B
#  + 4000 Colin_Poche_P + 6500 Colin_Rea_P + 8000 Collin_McHugh_P
#  + 5400 Colten_Brewer_P + 2100 Colton_Shaver_C + 7200 Conner_Menez_P
#  + 4000 Connor_Brogdon_P + 4000 Connor_Seabold_P + 2000 Connor_Wong_C
#  + 8100 Corbin_Burnes_P + 2000 Corbin_Carroll_OF + 6000 Corbin_Martin_P
#  + 10200 Corey_Kluber_P + 4000 Corey_Knebel_P + 8600 Corey_Oswalt_P
#  + 2400 Corey_Ray_OF + 5200 Corey_Seager_SS + 6500 Cory_Gearrin_P
#  + 6500 Craig_Kimbrel_P + 9500 Cristian_Javier_P + 3000 Cristian_Pache_OF
#  + 4000 Cristopher_Sanchez_P + 4000 Cy_Sneed_P + 4900 DJ_LeMahieu_2B
#  + 4900 DJ_LeMahieu_3B + 2000 DJ_Peters_OF + 2700 DJ_Stewart_OF
#  + 6500 DL_Hall_P + 4000 Dakota_Bacus_P + 4000 Dakota_Chalmers_P
#  + 6500 Dakota_Mekkes_P + 8700 Dallas_Keuchel_P + 4000 Damon_Jones_P
#  + 4000 Dan_Otero_P + 6500 Dan_Winkler_P + 4500 Dane_Dunning_P
#  + 4000 Daniel_Alvarez_P + 4000 Daniel_Bard_P + 2000 Daniel_Descalso_2B
#  + 4000 Daniel_Espino_P + 5400 Daniel_Hudson_P + 2100 Daniel_Johnson_OF
#  + 4000 Daniel_Lynch_P + 4000 Daniel_Murphy_1B + 5400 Daniel_Norris_P
#  + 4000 Daniel_Tillo_P + 4000 Daniel_Zamora_P + 4000 Danny_Coulombe_P
#  + 6700 Danny_Duffy_P + 6500 Danny_Hultzen_P + 3200 Danny_Mendick_2B
#  + 3700 Danny_Santana_1B + 4900 Dansby_Swanson_SS + 2700 Darin_Ruf_OF
#  + 4000 Dario_Agrazal_P + 6900 Darwinzon_Hernandez_P + 2000 Daulton_Varsho_C
#  + 2000 Daulton_Varsho_OF + 2400 David_Bote_3B + 3000 David_Dahl_OF
#  + 2600 David_Freitas_1B + 4000 David_Hale_P + 4000 David_Hernandez_P
#  + 6500 David_Hess_P + 4000 David_McKay_P + 3700 David_Peralta_OF
#  + 7600 David_Peterson_P + 4000 David_Phelps_P + 4000 David_Robertson_P
#  + 3000 David_Rodriguez_C + 2600 Dawel_Lugo_3B + 2800 Daz_Cameron_OF
#  + 4000 DeMarcus_Evans_P + 6500 Dean_Kremer_P + 4000 Deivi_Garcia_P
#  + 2500 Deivy_Grullon_C + 2100 Delino_DeShields_OF + 4000 Dellin_Betances_P
#  + 5200 Dennis_Santana_P + 4000 Deolis_Guerra_P + 4000 Dereck_Rodriguez_P
#  + 3100 Derek_Dietrich_1B + 3100 Derek_Dietrich_2B + 2800 Derek_Hill_OF
#  + 6100 Derek_Holland_P + 4000 Derek_Law_P + 6300 Devin_Smeltzer_P
#  + 4000 Devin_Williams_P + 4400 Didi_Gregorius_SS + 2000 Diego_Cartaya_C
#  + 5200 Diego_Castillo_P + 2800 Dillon_Dingler_C + 6500 Dillon_Maples_P
#  + 6500 Dillon_Tate_P + 3600 Dom_Nunez_C + 4000 Domingo_Acevedo_P
#  + 2400 Domingo_Santana_OF + 2000 Dominic_Fletcher_OF + 4000 Dominic_Leone_P
#  + 4600 Dominic_Smith_1B + 4600 Dominic_Smith_OF + 4700 Donovan_Solano_2B
#  + 4000 Dovydas_Neverauskas_P + 4000 Drew_Anderson_P + 2300 Drew_Butera_C
#  + 2500 Drew_Maggi_2B + 2500 Drew_Maggi_3B + 4000 Drew_Rasmussen_P
#  + 4000 Drew_Smith_P + 7300 Drew_Smyly_P + 2800 Drew_Waters_OF
#  + 6500 Duane_Underwood_Jr._P + 2100 Dustin_Garneau_C + 9100 Dustin_May_P
#  + 2000 Dustin_Pedroia_2B + 3100 Dwight_Smith_Jr._OF + 8800 Dylan_Cease_P
#  + 2200 Dylan_Cozens_OF + 4000 Dylan_File_P + 4000 Dylan_Floro_P
#  + 4100 Eddie_Rosario_OF + 4000 Edgar_Garcia_P + 6900 Edinson_Volquez_P
#  + 4000 Eduardo_Escobar_3B + 3600 Eduardo_Nunez_2B + 3600 Eduardo_Nunez_3B
#  + 10500 Eduardo_Rodriguez_P + 4000 Edubray_Ramos_P + 4000 Edwar_Colina_P
#  + 4000 Edwin_Diaz_P + 4000 Edwin_Encarnacion_1B + 3100 Edwin_Rios_1B
#  + 3100 Edwin_Rios_3B + 4000 Edwin_Uceta_P + 2700 Ehire_Adrianza_3B
#  + 2700 Ehire_Adrianza_SS + 4000 Eli_Morgan_P + 2400 Eli_White_2B
#  + 3700 Elias_Diaz_C + 2000 Eliezer_Alfonzo_C + 4900 Eloy_Jimenez_OF
#  + 2700 Elvis_Andrus_SS + 2000 Emilio_Bonifacio_OF + 4000 Emilio_Vargas_P
#  + 3000 Ender_Inciarte_OF + 4000 Enoli_Paredes_P + 7000 Enyel_De_Los_Santos_P
#  + 4000 Erasmo_Ramirez_P + 3300 Eric_Haase_C + 6500 Eric_Hanhold_P
#  + 6600 Eric_Lauer_P + 2700 Eric_Sogard_3B + 2400 Eric_Stamets_SS
#  + 3600 Eric_Thames_1B + 4000 Eric_Yardley_P + 5200 Erick_Fedde_P
#  + 2100 Erick_Mejia_3B + 2100 Erick_Mejia_OF + 3500 Erik_Gonzalez_3B
#  + 3500 Erik_Gonzalez_SS + 2900 Erik_Kratz_C + 2200 Ernie_Clement_SS
#  + 2100 Esteban_Quiroz_2B + 2600 Estevan_Florial_OF + 4000 Ethan_Hankins_P
#  + 4000 Ethan_Small_P + 4200 Evan_Longoria_3B + 4000 Evan_Marshall_P
#  + 6500 Evan_Phillips_P + 4000 Fernando_Abad_P + 4000 Forrest_Whitley_P
#  + 4000 Foster_Griffin_P + 8100 Framber_Valdez_P + 2200 Franchy_Cordero_OF
#  + 5300 Francisco_Lindor_SS + 4000 Francisco_Liriano_P
#  + 3000 Frank_Schwindel_1B + 4000 Franklin_Perez_P + 5800 Franklyn_Kilome_P
#  + 4100 Franmil_Reyes_OF + 5300 Freddie_Freeman_1B + 2100 Freddy_Fermin_C
#  + 8200 Freddy_Peralta_P + 4000 Gabe_Speier_P + 2000 Gabriel_Arias_SS
#  + 4000 Garrett_Cleavinger_P + 4000 Garrett_Crochet_P
#  + 4200 Garrett_Hampson_OF + 2400 Garrett_Stubbs_C + 4300 Gary_Sanchez_C
#  + 4000 Gavin_Lux_2B + 4000 Geoff_Hartlieb_P + 4400 George_Springer_OF
#  + 2200 George_Valera_OF + 2000 Geraldo_Perdomo_SS + 4000 Gerardo_Carrillo_P
#  + 7800 German_Marquez_P + 10000 Gerrit_Cole_P + 4900 Giancarlo_Stanton_OF
#  + 2600 Gilberto_Celestino_OF + 7500 Gio_Gonzalez_P + 3900 Gio_Urshela_3B
#  + 6500 Glenn_Sparkman_P + 4600 Gleyber_Torres_SS + 2000 Gordon_Beckham_2B
#  + 6500 Grant_Dayton_P + 2600 Grayson_Greiner_C + 3100 Greg_Bird_1B
#  + 4000 Greg_Holland_P + 2800 Gregory_Polanco_OF + 5900 Gregory_Soto_P
#  + 4900 Hanser_Alberto_2B + 3100 Harold_Castro_2B + 3100 Harold_Castro_OF
#  + 6500 Heath_Fillmyer_P + 4000 Heath_Hembree_P + 4000 Hector_Neris_P
#  + 4000 Hector_Rondon_P + 4000 Hector_Santiago_P + 6500 Hector_Velazquez_P
#  + 2600 Heliot_Ramos_OF + 2000 Henri_Lartigue_C + 2400 Hernan_Perez_2B
#  + 2400 Hernan_Perez_SS + 7800 Homer_Bailey_P + 4100 Howie_Kendrick_1B
#  + 5600 Huascar_Ynoa_P + 2100 Humberto_Arteaga_2B + 2100 Humberto_Arteaga_SS
#  + 4300 Hunter_Dozier_OF + 6500 Hunter_Harvey_P + 2800 Hunter_Pence_OF
#  + 3100 Hunter_Renfroe_OF + 4000 Hunter_Strickland_P + 4000 Hunter_Wood_P
#  + 6800 Ian_Anderson_P + 4700 Ian_Gibaut_P + 4000 Ian_Hamilton_P
#  + 4100 Ian_Happ_OF + 4600 Ian_Kennedy_P + 4200 Ian_Miller_OF
#  + 3600 Ildemaro_Vargas_1B + 3600 Ildemaro_Vargas_2B + 6500 Isaac_Mattson_P
#  + 2800 Isaac_Paredes_3B + 2600 Isiah_Kiner_Falefa_SS + 6300 Ivan_Nova_P
#  + 8500 J.A._Happ_P + 6100 J.B._Bukauskas_P + 4300 J.D._Davis_3B
#  + 5000 J.D._Martinez_OF + 4000 J.P._Feyereisen_P + 5100 J.T._Realmuto_C
#  + 5700 JT_Brubaker_P + 2400 JT_Riddle_3B + 2400 JT_Riddle_OF
#  + 3000 JaCoby_Jones_OF + 4000 Jace_Fry_P + 2300 Jace_Peterson_2B
#  + 2300 Jace_Peterson_OF + 2500 Jack_Mayfield_3B + 2500 Jack_Mayfield_SS
#  + 6500 Jack_Patterson_P + 2400 Jackie_Bradley_Jr._OF + 4000 Jackson_Kowar_P
#  + 4000 Jackson_Rutledge_P + 4000 Jacob_Lindgren_P + 2400 Jacob_Nottingham_C
#  + 2700 Jacob_Stallings_C + 6500 Jacob_Webb_P + 10200 Jacob_deGrom_P
#  + 4000 Jairo_Diaz_P + 6800 Jake_Arrieta_P + 2500 Jake_Bauers_1B
#  + 2500 Jake_Bauers_OF + 3200 Jake_Cave_OF + 2300 Jake_Elmore_3B
#  + 2300 Jake_Elmore_OF + 7100 Jake_Faria_P + 2000 Jake_Hager_1B
#  + 2000 Jake_Hager_2B + 4000 Jake_Irvin_P + 2000 Jake_Lamb_1B
#  + 2800 Jake_Marisnick_OF + 4000 Jake_McGee_P + 2100 Jake_Meyers_OF
#  + 4000 Jake_Newberry_P + 2000 Jake_Noll_2B + 9000 Jake_Odorizzi_P
#  + 3100 Jake_Rogers_C + 7500 Jakob_Junis_P + 2000 Jakson_Reetz_C
#  + 6600 Jalen_Beeks_P + 4000 James_Bourque_P + 4000 James_Karinchak_P
#  + 4000 James_Marvel_P + 4400 James_McCann_C + 6500 James_Norwood_P
#  + 8200 James_Paxton_P + 4000 James_Pazos_P + 4200 James_Sherfy_P
#  + 4000 Jameson_Taillon_P + 2100 Jamie_Ritchie_C + 4000 Jandel_Gustave_P
#  + 4000 Jared_Hughes_P + 2100 Jared_Oliva_OF + 6500 Jared_Shuster_P
#  + 4000 Jarlin_Garcia_P + 3000 Jarrett_Parker_OF + 2500 Jarrod_Dyson_OF
#  + 6500 Jason_Adam_P + 2300 Jason_Heyward_OF + 2800 Jason_Kipnis_2B
#  + 2000 Jason_Martin_OF + 6500 Jasseel_De_La_Cruz_P + 4500 Javier_Baez_SS
#  + 4000 Javy_Guerra_P + 2500 Jay_Bruce_OF + 2500 Jaylin_Davis_OF
#  + 4000 Jean_Carlos_Mejia_P + 4500 Jean_Segura_2B + 4500 Jean_Segura_3B
#  + 2300 Jed_Lowrie_2B + 4400 Jedd_Gyorko_1B + 4400 Jedd_Gyorko_3B
#  + 6500 Jeff_Hoffman_P + 3100 Jeff_Mathis_C + 3400 Jeff_McNeil_2B
#  + 3400 Jeff_McNeil_OF + 6400 Jeff_Samardzija_P + 4000 Jeffrey_Springs_P
#  + 4000 Jefry_Rodriguez_P + 3900 Jeimer_Candelario_1B + 2100 Jeison_Guzman_SS
#  + 4000 Jeremy_Beasley_P + 6500 Jeremy_Jeffress_P + 6500 Jeremy_Walker_P
#  + 4100 Jesse_Chavez_P + 4000 Jesse_Hahn_P + 4000 Jeurys_Familia_P
#  + 6500 Jharel_Cotton_P + 4000 Jhoan_Duran_P + 6500 Jhoulys_Chacin_P
#  + 2000 Ji_Hwan_Bae_2B + 2000 Ji_Hwan_Bae_SS + 3300 Ji_Man_Choi_1B
#  + 4000 Jimmy_Cordero_P + 4000 Jimmy_Herget_P + 4000 Jimmy_Lambert_P
#  + 7700 Jimmy_Nelson_P + 7900 JoJo_Romero_P + 4000 Joan_Adon_P
#  + 3700 Joc_Pederson_OF + 4000 Joe_Biagini_P + 4000 Joe_Harvey_P
#  + 4000 Joe_Jimenez_P + 4600 Joe_Kelly_P + 4000 Joe_Mantiply_P
#  + 2500 Joe_McCarthy_OF + 5700 Joe_Musgrove_P + 5400 Joe_Palumbo_P
#  + 4000 Joe_Ryan_P + 4000 Joel_Payamps_P + 4000 Joely_Rodriguez_P
#  + 4000 Joey_Bart_C + 4000 Joey_Cantillo_P + 4700 Joey_Gallo_OF
#  + 2500 Joey_Rickard_OF + 3600 Joey_Wendle_2B + 3100 Johan_Camargo_2B
#  + 4000 John_Curtiss_P + 2000 John_Hicks_1B + 2000 John_Hicks_C
#  + 5400 John_Means_P + 2100 John_Ryan_Murphy_C + 4000 John_Schreiber_P
#  + 3000 Johneshwy_Fargas_OF + 7400 Johnny_Cueto_P + 4000 Jojanse_Torres_P
#  + 5100 Jon_Duplantier_P + 6300 Jon_Gray_P + 2000 Jon_Jay_OF
#  + 9400 Jon_Lester_P + 3100 Jonathan_Arauz_2B + 3100 Jonathan_Arauz_3B
#  + 6400 Jonathan_Hernandez_P + 4000 Jonathan_Holder_P
#  + 7000 Jonathan_Loaisiga_P + 2000 Jonathan_Lucroy_C + 2700 Jonathan_Morales_C
#  + 4300 Jonathan_Schoop_2B + 4000 Jonathan_Stiever_P + 4000 Jordan_Humphreys_P
#  + 2600 Jordan_Luplow_OF + 7200 Jordan_Lyles_P + 7800 Jordan_Montgomery_P
#  + 4000 Jordan_Zimmermann_P + 2700 Jordy_Mercer_3B + 2700 Jordy_Mercer_SS
#  + 5400 Jorge_Alcala_P + 2900 Jorge_Bonifacio_OF + 5500 Jorge_Lopez_P
#  + 4800 Jorge_Polanco_SS + 4200 Jorge_Soler_OF + 5500 Jose_Abreu_1B
#  + 5000 Jose_Altuve_2B + 5100 Jose_Alvarado_P + 4200 Jose_Alvarez_P
#  + 8200 Jose_Berrios_P + 4000 Jose_Cisnero_P + 4100 Jose_Iglesias_SS
#  + 5400 Jose_Leclerc_P + 4000 Jose_Mujica_P + 2000 Jose_Osuna_3B
#  + 2000 Jose_Osuna_OF + 2000 Jose_Peraza_2B + 6500 Jose_Quintana_P
#  + 5400 Jose_Ramirez_3B + 4000 Jose_Ruiz_P + 2600 Jose_Siri_OF
#  + 2800 Jose_Trevino_C + 4000 Jose_Urquidy_P + 3500 Josh_Bell_1B
#  + 3300 Josh_Donaldson_3B + 5600 Josh_Fleming_P + 2000 Josh_Fuentes_1B
#  + 4000 Josh_Green_P + 4500 Josh_Hader_P + 3800 Josh_Harrison_3B
#  + 3800 Josh_Harrison_OF + 8700 Josh_James_P + 2100 Josh_Jung_3B
#  + 6600 Josh_Lindblom_P + 2100 Josh_Lowe_3B + 2000 Josh_Naylor_OF
#  + 4000 Josh_Osich_P + 2200 Josh_Phegley_C + 3200 Josh_Reddick_OF
#  + 2000 Josh_Rojas_2B + 2000 Josh_Rojas_OF + 4000 Josh_Sborz_P
#  + 4000 Josh_Staumont_P + 4500 Josh_Taylor_P + 5800 Josh_Tomlin_P
#  + 4000 Josiah_Gray_P + 2000 Juan_Centeno_C + 6500 Juan_Gamez_P
#  + 2300 Juan_Graterol_C + 4000 Juan_Minaya_P + 4000 Juan_Nicasio_P
#  + 5700 Juan_Soto_OF + 9700 Julio_Urias_P + 4000 Junior_Guerra_P
#  + 4000 Justin_Grimm_P + 3800 Justin_Smoak_1B + 6500 Justin_Steele_P
#  + 4000 Justin_Topa_P + 4800 Justin_Turner_3B + 4000 Justin_Verlander_P
#  + 4000 Justin_Wilson_P + 2600 Kean_Wong_2B + 6900 Keegan_Akin_P
#  + 6500 Keegan_Thompson_P + 4100 Keibert_Ruiz_C + 2100 Kelvin_Gutierrez_3B
#  + 5700 Kenley_Jansen_P + 4000 Kent_Emanuel_P + 9600 Kenta_Maeda_P
#  + 2300 Keon_Broxton_OF + 4000 Keone_Kela_P + 5300 Keston_Hiura_2B
#  + 5200 Ketel_Marte_2B + 4000 Keury_Mella_P + 2800 Kevan_Smith_C
#  + 2000 Kevin_Cron_1B + 6600 Kevin_Gausman_P + 4000 Kevin_Ginkel_P
#  + 2300 Kevin_Kiermaier_OF + 2100 Kevin_Kramer_2B + 2100 Kevin_Kramer_OF
#  + 4000 Kevin_McCarthy_P + 3800 Kevin_Newman_2B + 3800 Kevin_Newman_SS
#  + 2100 Kevin_Padlo_3B + 3200 Kevin_Pillar_OF + 2100 Kevin_Plawecki_C
#  + 4000 Kevin_Smith_P + 2100 Khalil_Lee_OF + 3900 Kike_Hernandez_2B
#  + 7200 Kohl_Stewart_P + 6800 Kolby_Allard_P + 4500 Kole_Calhoun_OF
#  + 4600 Kris_Bryant_3B + 4600 Kris_Bryant_OF + 6500 Kris_Bubic_P
#  + 3900 Kurt_Suzuki_C + 4000 Kyle_Cody_P + 4000 Kyle_Crick_P
#  + 4000 Kyle_Finnegan_P + 7200 Kyle_Freeland_P + 5800 Kyle_Funkhouser_P
#  + 2200 Kyle_Garlick_OF + 6100 Kyle_Gibson_P + 5600 Kyle_Hart_P
#  + 9200 Kyle_Hendricks_P + 2600 Kyle_Higashioka_C + 2700 Kyle_Holder_SS
#  + 2100 Kyle_Isbel_OF + 5500 Kyle_McGowin_P + 6500 Kyle_Muller_P
#  + 4000 Kyle_Nelson_P + 6500 Kyle_Ryan_P + 4300 Kyle_Schwarber_OF
#  + 4500 Kyle_Tucker_OF + 6500 Kyle_Wright_P + 6500 Kyle_Zimmer_P
#  + 3000 LaMonte_Wade_Jr._OF + 9200 Lance_Lynn_P + 8900 Lance_McCullers_Jr._P
#  + 4000 Landon_Knack_P + 2100 Leody_Taveras_OF + 5100 Leury_Garcia_2B
#  + 5100 Leury_Garcia_SS + 4000 Levi_Kelly_P + 8400 Lewis_Thorpe_P
#  + 4000 Logan_Allen_P + 2700 Logan_Brown_C + 3200 Logan_Morrison_1B
#  + 6800 Logan_Webb_P + 3700 Lorenzo_Cain_OF + 10400 Lucas_Giolito_P
#  + 2100 Lucius_Fox_2B + 3400 Luis_Arraez_2B + 4000 Luis_Avilan_P
#  + 4000 Luis_Cessa_P + 4000 Luis_Frias_P + 3300 Luis_Garcia_2B
#  + 4000 Luis_Garcia_P + 4000 Luis_Garcia_P + 4000 Luis_Gil_P
#  + 2000 Luis_Gonzalez_OF + 2800 Luis_Guillorme_2B + 2800 Luis_Guillorme_SS
#  + 4000 Luis_Madero_P + 4000 Luis_Medina_P + 4700 Luis_Robert_OF
#  + 4000 Luis_Severino_P + 2700 Luis_Toribio_3B + 3800 Luis_Urias_2B
#  + 3800 Luis_Urias_3B + 4000 Luke_Farrell_P + 6500 Luke_Jackson_P
#  + 2200 Luke_Maile_C + 2000 Luke_Raley_OF + 4400 Luke_Voit_1B
#  + 7600 Luke_Weaver_P + 2100 MJ_Melendez_C + 6800 Madison_Bumgarner_P
#  + 3600 Maikel_Franco_3B + 4200 Manny_Pina_C + 2300 Manuel_Margot_OF
#  + 6500 Manuel_Rodriguez_P + 4200 Marcell_Ozuna_OF + 2300 Marco_Hernandez_2B
#  + 2200 Marco_Luciano_SS + 10300 Marcus_Stroman_P + 4000 Marcus_Walden_P
#  + 2100 Marcus_Wilson_OF + 2400 Mario_Feliciano_C + 2300 Mark_Mathias_OF
#  + 6500 Mark_Melancon_P + 2200 Mark_Zagunis_OF + 4000 Marshall_Kasowski_P
#  + 4400 Martin_Maldonado_C + 6300 Martin_Perez_P + 3900 Marwin_Gonzalez_3B
#  + 3900 Marwin_Gonzalez_OF + 7600 Masahiro_Tanaka_P + 2000 Mason_Martin_1B
#  + 2000 Mason_Martin_OF + 2900 Mason_Williams_OF + 5700 Matt_Barnes_P
#  + 2600 Matt_Beaty_1B + 4000 Matt_Blackham_P + 4000 Matt_Cronin_P
#  + 3600 Matt_Duffy_3B + 3600 Matt_Duffy_SS + 4000 Matt_Foster_P
#  + 4000 Matt_Grace_P + 4900 Matt_Hall_P + 5300 Matt_Harvey_P
#  + 3400 Matt_Kemp_OF + 4000 Matt_Manning_P + 2100 Matt_Reynolds_2B
#  + 2100 Matt_Reynolds_3B + 7000 Matt_Wisler_P + 7600 Matthew_Boyd_P
#  + 2800 Mauricio_Dubon_OF + 2800 Mauricio_Dubon_SS + 4000 Mauricio_Llovera_P
#  + 9200 Max_Fried_P + 4400 Max_Kepler_OF + 4000 Max_Kranick_P
#  + 2600 Max_McDowell_C + 2400 Max_Moroff_2B + 2400 Max_Moroff_SS
#  + 5200 Max_Muncy_1B + 5200 Max_Muncy_3B + 11000 Max_Scherzer_P
#  + 2100 Meibrys_Viloria_C + 2800 Melky_Cabrera_OF + 4000 Melvin_Adon_P
#  + 8700 Merrill_Kelly_P + 2000 Michael_A._Taylor_OF + 6500 Michael_Baumann_P
#  + 3200 Michael_Brantley_OF + 2000 Michael_Busch_2B + 3400 Michael_Chavis_1B
#  + 3400 Michael_Chavis_2B + 4300 Michael_Conforto_OF + 4000 Michael_Feliz_P
#  + 5400 Michael_Fulmer_P + 4000 Michael_Grove_P + 4000 Michael_King_P
#  + 2100 Michael_Papierski_C + 2000 Michael_Perez_C + 7900 Michael_Pineda_P
#  + 8000 Michael_Wacha_P + 2000 Micker_Adolfo_OF + 2000 Miguel_Amaya_C
#  + 2800 Miguel_Andujar_3B + 2800 Miguel_Andujar_OF + 3600 Miguel_Cabrera_1B
#  + 6500 Miguel_Castro_P + 4000 Miguel_Del_Pozo_P + 5000 Miguel_Sano_1B
#  + 4000 Miguel_Yajure_P + 4600 Mike_Brosseau_1B + 4600 Mike_Brosseau_2B
#  + 10300 Mike_Foltynewicz_P + 3200 Mike_Ford_1B + 2100 Mike_Freeman_2B
#  + 2100 Mike_Freeman_OF + 6500 Mike_Montgomery_P + 7500 Mike_Shawaryn_P
#  + 9600 Mike_Soroka_P + 3300 Mike_Tauchman_OF + 5800 Mike_Yastrzemski_OF
#  + 3400 Mike_Zunino_C + 2000 Mikie_Mahtook_OF + 4900 Mitch_Garver_C
#  + 4000 Mitch_Keller_P + 4000 Mitch_White_P + 6100 Mookie_Betts_OF
#  + 2400 Myles_Straw_OF + 3700 Nate_Lowe_1B + 3700 Nate_Lowe_3B
#  + 5900 Nathan_Eovaldi_P + 2000 Neil_Walker_1B + 2000 Neil_Walker_2B
#  + 6200 Nelson_Cruz_OF + 4300 Nick_Ahmed_SS + 4000 Nick_Anderson_P
#  + 4000 Nick_Burdi_P + 2000 Nick_Ciuffo_C + 2100 Nick_Dini_C
#  + 4000 Nick_Goody_P + 2500 Nick_Gordon_2B + 2100 Nick_Heath_OF
#  + 2900 Nick_Madrigal_2B + 3600 Nick_Markakis_OF + 2000 Nick_Martini_OF
#  + 4000 Nick_Mears_P + 4000 Nick_Nelson_P + 2100 Nick_Pratto_1B
#  + 4000 Nick_Ramirez_P + 4000 Nick_Sandlin_P + 3000 Nick_Solak_2B
#  + 3000 Nick_Solak_OF + 2100 Nick_Tanielu_2B + 2100 Nick_Tanielu_3B
#  + 4000 Nick_Tropeano_P + 4000 Nick_Wells_P + 4000 Nick_Wittgren_P
#  + 2200 Nicky_Delmonico_OF + 2500 Nicky_Lopez_2B + 2100 Nico_Hoerner_2B
#  + 2100 Nico_Hoerner_3B + 4000 Nik_Turley_P + 4200 Niko_Goodrum_SS
#  + 4000 Nivaldo_Rodriguez_P + 9100 Noah_Syndergaard_P + 5600 Nolan_Arenado_3B
#  + 4000 Nolan_Blackwood_P + 2200 Nolan_Jones_3B + 2400 Nomar_Mazara_OF
#  + 4000 Oliver_Drake_P + 4000 Oliver_Perez_P + 2000 Omar_Estevez_2B
#  + 2000 Omar_Estevez_SS + 3400 Omar_Narvaez_C + 2000 Oneil_Cruz_SS
#  + 3000 Orlando_Arcia_SS + 2100 Oscar_Hernandez_C + 2100 Oscar_Mercado_OF
#  + 3700 Ozzie_Albies_2B + 2000 P.J._Higgins_C + 2700 Pablo_Sandoval_1B
#  + 3400 Pat_Valaika_OF + 3400 Pat_Valaika_SS + 10200 Patrick_Corbin_P
#  + 3300 Patrick_Mazeika_C + 6500 Patrick_Weigel_P + 6500 Paul_Fry_P
#  + 4000 Paul_Sewald_P + 2000 Pavin_Smith_1B + 4000 Pedro_Baez_P
#  + 4600 Pedro_Severino_C + 4400 Pete_Alonso_1B + 4000 Pete_Fairbanks_P
#  + 6500 Peter_Lambert_P + 4000 Phil_Bickford_P + 3300 Phil_Gosselin_2B
#  + 3300 Phil_Gosselin_OF + 4000 Phil_Maton_P + 6500 Philip_Pfeifer_P
#  + 4000 Phillip_Diehl_P + 3500 Phillip_Evans_3B + 3500 Phillip_Evans_OF
#  + 5000 Phillips_Valdez_P + 5000 Rafael_Devers_3B + 2000 Rafael_Marchan_C
#  + 4000 Rafael_Montero_P + 4000 Raimel_Tapia_OF + 4000 Ralph_Garza_Jr._P
#  + 4000 Ramon_Rosso_P + 2700 Ramon_Urias_2B + 2500 Randy_Arozarena_OF
#  + 8200 Randy_Dobnak_P + 4000 Randy_Rosario_P + 7100 Ranger_Suarez_P
#  + 2100 Raudy_Read_C + 6000 Ray_Black_P + 4000 Reggie_McClain_P
#  + 4500 Renato_Nunez_1B + 3200 Rene_Rivera_C + 6500 Rex_Brothers_P
#  + 4000 Reyes_Moronta_P + 5800 Reynaldo_Lopez_P + 4600 Rhys_Hoskins_1B
#  + 7300 Rich_Hill_P + 7300 Richard_Lovelady_P + 4000 Richard_Rodriguez_P
#  + 3000 Richie_Martin_SS + 7800 Rick_Porcello_P + 6900 Rico_Garcia_P
#  + 2800 Riley_Greene_OF + 4000 Riley_Smith_P + 4100 Rio_Ruiz_3B
#  + 2000 Rob_Refsnyder_1B + 2000 Rob_Refsnyder_OF + 5700 Robbie_Erlin_P
#  + 4500 Robert_Gsellman_P + 4000 Robert_Stock_P + 4000 Roberto_Osuna_P
#  + 2700 Roberto_Perez_C + 4400 Robinson_Cano_2B + 2900 Robinson_Chirinos_C
#  + 4000 Robinson_Leyer_P + 2000 Rocky_Gale_C + 2000 Rodolfo_Castro_2B
#  + 2000 Rodolfo_Castro_SS + 4000 Roenis_Elias_P + 4000 Rogelio_Armenteros_P
#  + 2100 Roman_Quinn_OF + 4800 Ronald_Acuna_Jr._OF + 6500 Ronald_Bolanos_P
#  + 2000 Ronald_Guzman_1B + 2000 Ronald_Torreyes_SS + 2100 Ronaldo_Hernandez_C
#  + 2100 Ronnie_Dawson_OF + 3500 Ronny_Rodriguez_2B + 4000 Rony_Garcia_P
#  + 2200 Rosell_Herrera_2B + 2200 Rosell_Herrera_OF + 6800 Ross_Detwiler_P
#  + 3400 Rougned_Odor_2B + 6500 Rowan_Wick_P + 2500 Royce_Lewis_SS
#  + 4400 Ryan_Brasier_P + 3900 Ryan_Braun_OF + 4000 Ryan_Burr_P
#  + 5200 Ryan_Castellani_P + 3000 Ryan_Cordell_OF + 4000 Ryan_Garton_P
#  + 2000 Ryan_Goins_3B + 2000 Ryan_Goins_OF + 2700 Ryan_Jeffers_C
#  + 2000 Ryan_LaMarre_OF + 2100 Ryan_McBroom_1B + 2100 Ryan_McBroom_OF
#  + 2700 Ryan_McKenna_OF + 4500 Ryan_McMahon_1B + 4500 Ryan_McMahon_2B
#  + 3500 Ryan_Mountcastle_OF + 4000 Ryan_Pepiot_P + 4000 Ryan_Pressly_P
#  + 4000 Ryan_Rolison_P + 4000 Ryan_Sherriff_P + 6500 Ryan_Tepera_P
#  + 4700 Ryan_Thompson_P + 4600 Ryan_Weber_P + 7000 Ryan_Yarbrough_P
#  + 4000 Ryley_Gilliam_P + 4000 Ryne_Harper_P + 3000 Ryon_Healy_1B
#  + 3000 Ryon_Healy_3B + 4500 Salvador_Perez_C + 4000 Sam_Clay_P
#  + 7300 Sam_Coonrod_P + 4000 Sam_Freeman_P + 4000 Sam_Hentges_P
#  + 2600 Sam_Hilliard_OF + 4000 Sam_Howard_P + 2000 Sam_Huff_C
#  + 4000 Sam_McWilliams_P + 4000 Sam_Selman_P + 4000 Sam_Wolff_P
#  + 2300 Sandy_Leon_C + 4000 Scott_Alexander_P + 4000 Scott_Barlow_P
#  + 4000 Scott_Blewett_P + 2000 Scott_Heineman_OF + 2000 Scott_Kingery_2B
#  + 2000 Scott_Kingery_OF + 4000 Scott_Moss_P + 4000 Scott_Oberg_P
#  + 4900 Sean_Doolittle_P + 4000 Sean_Gilmartin_P + 6000 Sean_Newcomb_P
#  + 4000 Sean_Poppen_P + 2100 Sebastian_Rivero_C + 2000 Seby_Zavala_C
#  + 4000 Seranthony_Dominguez_P + 2800 Sergio_Alcantara_SS + 4000 Sergio_Romo_P
#  + 2000 Seth_Beer_OF + 4000 Seth_Lugo_P + 4000 Seth_Romero_P
#  + 2100 Seuly_Matias_OF + 11000 Shane_Bieber_P + 6500 Shane_Greene_P
#  + 4000 Shane_McClanahan_P + 4000 Shao_Ching_Chiang_P + 4800 Shaun_Anderson_P
#  + 6500 Shawn_Armstrong_P + 4000 Shawn_Dubin_P + 2700 Shea_Langeliers_C
#  + 5000 Shelby_Miller_P + 2000 Sherten_Apostel_3B + 2700 Shin_Soo_Choo_OF
#  + 4600 Silvino_Bracho_P + 2300 Socrates_Brito_OF + 5800 Spencer_Howard_P
#  + 2800 Spencer_Torkelson_3B + 8700 Spencer_Turnbull_P
#  + 4100 Starlin_Castro_2B + 4000 Stefan_Crichton_P + 10000 Stephen_Strasburg_P
#  + 3600 Stephen_Vogt_C + 4000 Stephen_Woods_Jr._P + 4000 Steve_Cishek_P
#  + 2300 Steven_Baron_C + 5400 Steven_Brault_P + 2500 Steven_Duggar_OF
#  + 4000 Steven_Fuentes_P + 6400 Steven_Matz_P + 2000 Steven_Souza_Jr._OF
#  + 2800 Stevie_Wilkerson_2B + 2800 Stevie_Wilkerson_OF + 4000 Tanner_Rainey_P
#  + 6500 Tanner_Scott_P + 6700 Tarik_Skubal_P + 4800 Taylor_Clarke_P
#  + 2800 Taylor_Davis_C + 7200 Taylor_Hearn_P + 2100 Taylor_Jones_1B
#  + 4000 Taylor_Rogers_P + 2100 Taylor_Walls_SS + 7500 Taylor_Widener_P
#  + 4000 Tayron_Guerrero_P + 2900 Thairo_Estrada_2B + 2900 Thairo_Estrada_SS
#  + 2400 Thomas_Dillard_1B + 2400 Thomas_Dillard_OF + 4000 Thomas_Szapucki_P
#  + 5600 Tim_Anderson_SS + 4000 Tim_Cate_P + 4000 Tim_Collins_P
#  + 2100 Tim_Federowicz_C + 2500 Tim_Locastro_OF + 2500 Todd_Frazier_3B
#  + 7200 Tom_Eshelman_P + 2800 Tomas_Nido_C + 2600 Tomas_Telis_1B
#  + 4000 Tommy_Henry_P + 4000 Tommy_Hunter_P + 4000 Tommy_Kahnle_P
#  + 8600 Tommy_Milone_P + 8400 Tony_Gonsolin_P + 4000 Tony_Watson_P
#  + 2900 Tony_Wolters_C + 6400 Touki_Toussaint_P + 2600 Travis_Blankenhorn_2B
#  + 3000 Travis_Demeritte_OF + 6500 Travis_Lakins_P + 2100 Travis_Swaggerty_OF
#  + 5400 Trea_Turner_SS + 2000 Tres_Barrera_C + 5900 Trevor_Cahill_P
#  + 4000 Trevor_Gott_P + 4000 Trevor_Kelley_P + 2600 Trevor_Larnach_OF
#  + 4000 Trevor_May_P + 6500 Trevor_Megill_P + 4000 Trevor_Oaks_P
#  + 5900 Trevor_Richards_P + 5700 Trevor_Story_SS + 6000 Trevor_Williams_P
#  + 3000 Trey_Mancini_1B + 3000 Trey_Mancini_OF + 7700 Trey_Supak_P
#  + 2400 Tristen_Lutz_OF + 6600 Triston_McKenzie_P + 2800 Troy_Stokes_Jr._OF
#  + 6500 Tucker_Davidson_P + 6500 Ty_Blach_P + 5200 Tyler_Alexander_P
#  + 6400 Tyler_Anderson_P + 4000 Tyler_Bashlor_P + 6300 Tyler_Beede_P
#  + 8700 Tyler_Chatwood_P + 6500 Tyler_Clippard_P + 4000 Tyler_Cyr_P
#  + 4000 Tyler_Duffey_P + 3800 Tyler_Flowers_C + 2200 Tyler_Freeman_SS
#  + 8400 Tyler_Glasnow_P + 4000 Tyler_Heineman_C + 4000 Tyler_Johnson_P
#  + 4000 Tyler_Kinley_P + 4000 Tyler_Lyons_P + 6500 Tyler_Matzek_P
#  + 2600 Tyler_Naquin_OF + 2300 Tyler_Nevin_1B + 2300 Tyler_Nevin_3B
#  + 4000 Tyler_Phillips_P + 4000 Tyler_Rogers_P + 2400 Tyler_Wade_2B
#  + 2400 Tyler_Wade_SS + 4000 Tyler_Zuber_P + 2800 Tyrone_Taylor_OF
#  + 6500 Tyson_Miller_P + 2000 Tzu_Wei_Lin_OF + 2000 Tzu_Wei_Lin_SS
#  + 4000 Victor_Arano_P + 3000 Victor_Caratini_C + 4000 Victor_Gonzalez_P
#  + 3200 Victor_Reyes_OF + 2000 Victor_Robles_OF + 2100 Vidal_Brujan_2B
#  + 6500 Vince_Velasquez_P + 4000 Wade_Davis_P + 6500 Wade_LeBlanc_P
#  + 10200 Walker_Buehler_P + 6500 Walker_Lockett_P + 2100 Wander_Franco_SS
#  + 4000 Wander_Suero_P + 4000 Wandy_Peralta_P + 4000 Wei_Chieh_Huang_P
#  + 4000 Wes_Benjamin_P + 5500 Whit_Merrifield_OF + 4900 Wil_Crowe_P
#  + 2500 Wilfredo_Tovar_SS + 2000 Will_Craig_1B + 4000 Will_Harris_P
#  + 3700 Will_Smith_C + 6500 Will_Smith_P + 2700 Will_Wilson_SS
#  + 3300 Willi_Castro_3B + 3300 Willi_Castro_SS + 3200 William_Contreras_C
#  + 2900 Willians_Astudillo_3B + 2900 Willians_Astudillo_C
#  + 2100 Willie_Calhoun_OF + 5000 Willson_Contreras_C + 3700 Willy_Adames_SS
#  + 2000 Wilmer_Difo_2B + 2000 Wilmer_Difo_SS + 4200 Wilmer_Flores_1B
#  + 4200 Wilmer_Flores_2B + 3500 Wilson_Ramos_C + 2000 Wyatt_Mathisen_2B
#  + 2000 Wyatt_Mathisen_3B + 5000 Xander_Bogaerts_SS + 4000 Yacksel_Rios_P
#  + 2000 Yadiel_Hernandez_OF + 2000 Yadiel_Rivera_2B + 2000 Yadiel_Rivera_OF
#  + 2000 Yairo_Munoz_OF + 2000 Yairo_Munoz_SS + 2600 Yan_Gomes_C
#  + 3700 Yandy_Diaz_3B + 3300 Yangervis_Solarte_2B + 3300 Yangervis_Solarte_OF
#  + 4800 Yasmani_Grandal_C + 4000 Yency_Almonte_P + 2000 Yermin_Mercedes_C
#  + 4000 Yoan_Aybar_P + 4500 Yoan_Lopez_P + 5300 Yoan_Moncada_3B
#  + 3800 Yoenis_Cespedes_OF + 4000 Yohander_Mendez_P + 3300 Yolmer_Sanchez_2B
#  + 2000 Yonathan_Daza_OF + 3400 Yonder_Alonso_1B + 4000 Yonny_Chirinos_P
#  + 5300 Yordan_Alvarez_OF + 2300 Yoshi_Tsutsugo_3B + 2300 Yoshi_Tsutsugo_OF
#  + 2100 Yu_Chang_3B + 11000 Yu_Darvish_P + 4800 Yuli_Gurriel_1B
#  + 9700 Zac_Gallen_P + 6900 Zach_Eflin_P + 2500 Zach_Green_3B
#  + 2000 Zach_McKinstry_SS + 8300 Zach_Plesac_P + 2000 Zach_Reks_OF
#  + 4000 Zack_Britton_P + 7000 Zack_Brown_P + 4000 Zack_Burdi_P
#  + 2900 Zack_Collins_C + 5600 Zack_Godley_P + 2500 Zack_Granite_OF
#  + 9900 Zack_Greinke_P + 4000 Zack_Littell_P + 2300 Zack_Short_SS
#  + 10300 Zack_Wheeler_P + 2600 Zander_Wiel_1B <= 50000
#
# _C2: AJ_Pollock_OF + Aaron_Barrett_P + Aaron_Bracho_SS + Aaron_Bummer_P
#  + Aaron_Civale_P + Aaron_Hicks_OF + Aaron_Judge_OF + Aaron_Loup_P
#  + Aaron_Nola_P + Aaron_Shortridge_P + Aaron_Slegers_P + Abiatal_Avelino_SS
#  + Abraham_Toro_3B + Adalberto_Mejia_P + Adalberto_Mondesi_SS + Adam_Cimber_P
#  + Adam_Duvall_OF + Adam_Eaton_OF + Adam_Engel_OF + Adam_Frazier_2B
#  + Adam_Frazier_OF + Adam_Haseley_OF + Adam_Kolarek_P + Adam_Morgan_P
#  + Adam_Ottavino_P + Adam_Plutko_P + Adbert_Alzolay_P + Addison_Russ_P
#  + Adeiny_Hechavarria_2B + Adeiny_Hechavarria_SS + Adley_Rutschman_C
#  + Adolis_Garcia_OF + Adonis_Medina_P + Adonis_Rosa_P + Adrian_Houser_P
#  + Adrian_Sanchez_2B + Alan_Trejo_SS + Albert_Abreu_P + Albert_Almora_Jr._OF
#  + Alec_Bohm_3B + Alec_Mills_P + Aledmys_Diaz_1B + Aledmys_Diaz_OF
#  + Alek_Thomas_OF + Alex_Avila_C + Alex_Bregman_3B + Alex_Claudio_P
#  + Alex_Cobb_P + Alex_Colome_P + Alex_De_Goti_2B + Alex_De_Goti_SS
#  + Alex_Dickerson_OF + Alex_Faedo_P + Alex_Gordon_OF + Alex_Jackson_C
#  + Alex_Kirilloff_1B + Alex_Kirilloff_OF + Alex_McRae_P + Alex_Speas_P
#  + Alex_Verdugo_OF + Alex_Wood_P + Alex_Young_P + Alexander_Canario_OF
#  + Alexander_Guillen_P + Alexander_Vizcaino_P + Ali_Sanchez_C
#  + Allan_de_San_Miguel_C + Amed_Rosario_SS + Anderson_Tejeda_2B
#  + Andre_Jackson_P + Andre_Scrubb_P + Andres_Gimenez_2B + Andres_Gimenez_SS
#  + Andrew_Benintendi_OF + Andrew_Chafin_P + Andrew_Kittredge_P
#  + Andrew_Knapp_C + Andrew_McCutchen_OF + Andrew_Stevenson_OF
#  + Andrew_Suarez_P + Andrew_Vaughn_1B + Andrew_Velazquez_SS + Andy_Ibanez_2B
#  + Andy_Young_3B + Angel_Perdomo_P + Anibal_Sanchez_P + Anthony_Banda_P
#  + Anthony_Castro_P + Anthony_Garcia_OF + Anthony_Rizzo_1B
#  + Anthony_Santander_OF + Anthony_Swarzak_P + Antoine_Kelly_P
#  + Antonio_Santos_P + Antonio_Senzatela_P + Aramis_Garcia_1B + Aramis_Garcia_C
#  + Aroldis_Chapman_P + Arquimedes_Gamboa_SS + Artie_Lewicki_P
#  + Asdrubal_Cabrera_1B + Asdrubal_Cabrera_3B + Asher_Wojciechowski_P
#  + Ashton_Goudeau_P + Austen_Williams_P + Austin_Barnes_C + Austin_Brice_P
#  + Austin_Cox_P + Austin_Hays_OF + Austin_Hedges_C + Austin_Meadows_OF
#  + Austin_Pruitt_P + Austin_Riley_3B + Austin_Romine_C + Austin_Slater_OF
#  + Austin_Voth_P + Austin_Wynns_C + Avisail_Garcia_OF + Beau_Burrows_P
#  + Beau_Taylor_C + Ben_Bowden_P + Ben_Braymer_P + Ben_Gamel_OF + Ben_Heller_P
#  + Bennett_Sousa_P + Bernardo_Flores_Jr._P + Billy_Hamilton_OF
#  + Blake_Cederlind_P + Blake_Parker_P + Blake_Rutherford_OF + Blake_Snell_P
#  + Blake_Swihart_C + Blake_Swihart_OF + Blake_Taylor_P + Blake_Treinen_P
#  + Blake_Walston_P + Bo_Naylor_C + Bo_Takahashi_P + Bobby_Bradley_1B
#  + Bobby_Dalbec_1B + Bobby_Dalbec_3B + Bobby_Miller_P + Bobby_Wahl_P
#  + Bobby_Witt_Jr._SS + Brad_Brach_P + Brad_Hand_P + Brad_Keller_P
#  + Brad_Peacock_P + Brad_Wieck_P + Braden_Shewmake_SS + Bradley_Zimmer_OF
#  + Brady_Policelli_C + Brady_Singer_P + Braeden_Ogle_P + Brailyn_Marquez_P
#  + Branden_Kline_P + Brandon_Bailey_P + Brandon_Belt_1B + Brandon_Bielak_P
#  + Brandon_Crawford_SS + Brandon_Dixon_1B + Brandon_Dixon_OF + Brandon_Lowe_2B
#  + Brandon_Lowe_OF + Brandon_Nimmo_OF + Brandon_Snyder_3B + Brandon_Waddell_P
#  + Brandon_Woodruff_P + Brandon_Workman_P + Brendan_McKay_P
#  + Brendan_Rodgers_2B + Brendan_Rodgers_SS + Brennen_Davis_OF
#  + Brent_Honeywell_Jr._P + Brent_Rooker_OF + Brent_Suter_P + Bret_Boswell_2B
#  + Bret_Boswell_3B + Brett_Anderson_P + Brett_Conine_P + Brett_Gardner_OF
#  + Brett_Martin_P + Brett_de_Geus_P + Brian_Johnson_P + Brice_Turang_SS
#  + Brock_Burke_P + Brock_Holt_3B + Brock_Holt_OF + Brooks_Kriske_P
#  + Brooks_Raley_P + Brusdar_Graterol_P + Bryan_Abreu_P + Bryan_Garcia_P
#  + Bryan_Holaday_C + Bryan_Reynolds_OF + Bryce_Harper_OF + Bryce_Jarvis_P
#  + Bryse_Wilson_P + Bubba_Starling_OF + Buck_Farmer_P + Byron_Buxton_OF
#  + C.J._Chatham_SS + C.J._Cron_1B + Cade_Cavalli_P + Cal_Quantrill_P
#  + Caleb_Baragar_P + Caleb_Ferguson_P + Caleb_Hamilton_C + Caleb_Simpson_P
#  + Caleb_Smith_P + Caleb_Thielbar_P + Cam_Gallagher_C + Cam_Hill_P
#  + Cameron_Maybin_OF + Camilo_Doval_P + Carlos_Carrasco_P + Carlos_Correa_SS
#  + Carlos_Estevez_P + Carlos_Hernandez_P + Carlos_Navas_P + Carlos_Rodon_P
#  + Carlos_Santana_1B + Carson_Fulmer_P + Carson_Kelly_C + Carson_Taylor_C
#  + Carter_Kieboom_3B + Casey_Mize_P + Casey_Sadler_P + Cedric_Mullins_OF
#  + Cesar_Hernandez_2B + Cesar_Puello_OF + Cesar_Valdez_P + Chad_Green_P
#  + Chad_Kuhl_P + Chad_Sobotka_P + Chadwick_Tromp_C + Chance_Adams_P
#  + Chance_Sisco_C + Chandler_Shepherd_P + Charlie_Blackmon_OF
#  + Charlie_Culberson_2B + Charlie_Culberson_OF + Charlie_Morton_P
#  + Chas_McCormick_OF + Chasen_Shreve_P + Chaz_Roe_P + Cheslor_Cuthbert_1B
#  + Cheslor_Cuthbert_3B + Chi_Chi_Gonzalez_P + Chris_Archer_P + Chris_Davis_1B
#  + Chris_Devenski_P + Chris_Herrmann_C + Chris_Iannetta_C + Chris_Martin_P
#  + Chris_Mazza_P + Chris_Owings_2B + Chris_Owings_OF + Chris_Rabago_C
#  + Chris_Rusin_P + Chris_Sale_P + Chris_Shaw_1B + Chris_Shaw_OF
#  + Chris_Stratton_P + Chris_Taylor_OF + Chris_Taylor_SS + Christian_Kelley_C
#  + Christian_Vazquez_C + Christian_Walker_1B + Christian_Yelich_OF
#  + Christin_Stewart_OF + Christopher_Morel_3B + Cionel_Perez_P
#  + Clarke_Schmidt_P + Clay_Holmes_P + Clayton_Andrews_P + Clayton_Beeter_P
#  + Clayton_Kershaw_P + Clint_Frazier_OF + Codi_Heuer_P + Cody_Allen_P
#  + Cody_Bellinger_1B + Cody_Bellinger_OF + Cody_Bolton_P + Cody_Carroll_P
#  + Cody_Ponce_P + Cody_Reed_P + Cody_Stashak_P + Cody_Thomas_OF
#  + Cole_Hamels_P + Cole_Irvin_P + Cole_Sulser_P + Cole_Tucker_OF
#  + Colin_Moran_1B + Colin_Poche_P + Colin_Rea_P + Collin_McHugh_P
#  + Colten_Brewer_P + Colton_Shaver_C + Conner_Menez_P + Connor_Brogdon_P
#  + Connor_Seabold_P + Connor_Wong_C + Corbin_Burnes_P + Corbin_Carroll_OF
#  + Corbin_Martin_P + Corey_Kluber_P + Corey_Knebel_P + Corey_Oswalt_P
#  + Corey_Ray_OF + Corey_Seager_SS + Cory_Gearrin_P + Craig_Kimbrel_P
#  + Cristian_Javier_P + Cristian_Pache_OF + Cristopher_Sanchez_P + Cy_Sneed_P
#  + DJ_LeMahieu_2B + DJ_LeMahieu_3B + DJ_Peters_OF + DJ_Stewart_OF + DL_Hall_P
#  + Dakota_Bacus_P + Dakota_Chalmers_P + Dakota_Mekkes_P + Dallas_Keuchel_P
#  + Damon_Jones_P + Dan_Otero_P + Dan_Winkler_P + Dane_Dunning_P
#  + Daniel_Alvarez_P + Daniel_Bard_P + Daniel_Descalso_2B + Daniel_Espino_P
#  + Daniel_Hudson_P + Daniel_Johnson_OF + Daniel_Lynch_P + Daniel_Murphy_1B
#  + Daniel_Norris_P + Daniel_Tillo_P + Daniel_Zamora_P + Danny_Coulombe_P
#  + Danny_Duffy_P + Danny_Hultzen_P + Danny_Mendick_2B + Danny_Santana_1B
#  + Dansby_Swanson_SS + Darin_Ruf_OF + Dario_Agrazal_P + Darwinzon_Hernandez_P
#  + Daulton_Varsho_C + Daulton_Varsho_OF + David_Bote_3B + David_Dahl_OF
#  + David_Freitas_1B + David_Hale_P + David_Hernandez_P + David_Hess_P
#  + David_McKay_P + David_Peralta_OF + David_Peterson_P + David_Phelps_P
#  + David_Robertson_P + David_Rodriguez_C + Dawel_Lugo_3B + Daz_Cameron_OF
#  + DeMarcus_Evans_P + Dean_Kremer_P + Deivi_Garcia_P + Deivy_Grullon_C
#  + Delino_DeShields_OF + Dellin_Betances_P + Dennis_Santana_P
#  + Deolis_Guerra_P + Dereck_Rodriguez_P + Derek_Dietrich_1B
#  + Derek_Dietrich_2B + Derek_Hill_OF + Derek_Holland_P + Derek_Law_P
#  + Devin_Smeltzer_P + Devin_Williams_P + Didi_Gregorius_SS + Diego_Cartaya_C
#  + Diego_Castillo_P + Dillon_Dingler_C + Dillon_Maples_P + Dillon_Tate_P
#  + Dom_Nunez_C + Domingo_Acevedo_P + Domingo_Santana_OF + Dominic_Fletcher_OF
#  + Dominic_Leone_P + Dominic_Smith_1B + Dominic_Smith_OF + Donovan_Solano_2B
#  + Dovydas_Neverauskas_P + Drew_Anderson_P + Drew_Butera_C + Drew_Maggi_2B
#  + Drew_Maggi_3B + Drew_Rasmussen_P + Drew_Smith_P + Drew_Smyly_P
#  + Drew_Waters_OF + Duane_Underwood_Jr._P + Dustin_Garneau_C + Dustin_May_P
#  + Dustin_Pedroia_2B + Dwight_Smith_Jr._OF + Dylan_Cease_P + Dylan_Cozens_OF
#  + Dylan_File_P + Dylan_Floro_P + Eddie_Rosario_OF + Edgar_Garcia_P
#  + Edinson_Volquez_P + Eduardo_Escobar_3B + Eduardo_Nunez_2B
#  + Eduardo_Nunez_3B + Eduardo_Rodriguez_P + Edubray_Ramos_P + Edwar_Colina_P
#  + Edwin_Diaz_P + Edwin_Encarnacion_1B + Edwin_Rios_1B + Edwin_Rios_3B
#  + Edwin_Uceta_P + Ehire_Adrianza_3B + Ehire_Adrianza_SS + Eli_Morgan_P
#  + Eli_White_2B + Elias_Diaz_C + Eliezer_Alfonzo_C + Eloy_Jimenez_OF
#  + Elvis_Andrus_SS + Emilio_Bonifacio_OF + Emilio_Vargas_P + Ender_Inciarte_OF
#  + Enoli_Paredes_P + Enyel_De_Los_Santos_P + Erasmo_Ramirez_P + Eric_Haase_C
#  + Eric_Hanhold_P + Eric_Lauer_P + Eric_Sogard_3B + Eric_Stamets_SS
#  + Eric_Thames_1B + Eric_Yardley_P + Erick_Fedde_P + Erick_Mejia_3B
#  + Erick_Mejia_OF + Erik_Gonzalez_3B + Erik_Gonzalez_SS + Erik_Kratz_C
#  + Ernie_Clement_SS + Esteban_Quiroz_2B + Estevan_Florial_OF + Ethan_Hankins_P
#  + Ethan_Small_P + Evan_Longoria_3B + Evan_Marshall_P + Evan_Phillips_P
#  + Fernando_Abad_P + Forrest_Whitley_P + Foster_Griffin_P + Framber_Valdez_P
#  + Franchy_Cordero_OF + Francisco_Lindor_SS + Francisco_Liriano_P
#  + Frank_Schwindel_1B + Franklin_Perez_P + Franklyn_Kilome_P
#  + Franmil_Reyes_OF + Freddie_Freeman_1B + Freddy_Fermin_C + Freddy_Peralta_P
#  + Gabe_Speier_P + Gabriel_Arias_SS + Garrett_Cleavinger_P + Garrett_Crochet_P
#  + Garrett_Hampson_OF + Garrett_Stubbs_C + Gary_Sanchez_C + Gavin_Lux_2B
#  + Geoff_Hartlieb_P + George_Springer_OF + George_Valera_OF
#  + Geraldo_Perdomo_SS + Gerardo_Carrillo_P + German_Marquez_P + Gerrit_Cole_P
#  + Giancarlo_Stanton_OF + Gilberto_Celestino_OF + Gio_Gonzalez_P
#  + Gio_Urshela_3B + Glenn_Sparkman_P + Gleyber_Torres_SS + Gordon_Beckham_2B
#  + Grant_Dayton_P + Grayson_Greiner_C + Greg_Bird_1B + Greg_Holland_P
#  + Gregory_Polanco_OF + Gregory_Soto_P + Hanser_Alberto_2B + Harold_Castro_2B
#  + Harold_Castro_OF + Heath_Fillmyer_P + Heath_Hembree_P + Hector_Neris_P
#  + Hector_Rondon_P + Hector_Santiago_P + Hector_Velazquez_P + Heliot_Ramos_OF
#  + Henri_Lartigue_C + Hernan_Perez_2B + Hernan_Perez_SS + Homer_Bailey_P
#  + Howie_Kendrick_1B + Huascar_Ynoa_P + Humberto_Arteaga_2B
#  + Humberto_Arteaga_SS + Hunter_Dozier_OF + Hunter_Harvey_P + Hunter_Pence_OF
#  + Hunter_Renfroe_OF + Hunter_Strickland_P + Hunter_Wood_P + Ian_Anderson_P
#  + Ian_Gibaut_P + Ian_Hamilton_P + Ian_Happ_OF + Ian_Kennedy_P + Ian_Miller_OF
#  + Ildemaro_Vargas_1B + Ildemaro_Vargas_2B + Isaac_Mattson_P
#  + Isaac_Paredes_3B + Isiah_Kiner_Falefa_SS + Ivan_Nova_P + J.A._Happ_P
#  + J.B._Bukauskas_P + J.D._Davis_3B + J.D._Martinez_OF + J.P._Feyereisen_P
#  + J.T._Realmuto_C + JT_Brubaker_P + JT_Riddle_3B + JT_Riddle_OF
#  + JaCoby_Jones_OF + Jace_Fry_P + Jace_Peterson_2B + Jace_Peterson_OF
#  + Jack_Mayfield_3B + Jack_Mayfield_SS + Jack_Patterson_P
#  + Jackie_Bradley_Jr._OF + Jackson_Kowar_P + Jackson_Rutledge_P
#  + Jacob_Lindgren_P + Jacob_Nottingham_C + Jacob_Stallings_C + Jacob_Webb_P
#  + Jacob_deGrom_P + Jairo_Diaz_P + Jake_Arrieta_P + Jake_Bauers_1B
#  + Jake_Bauers_OF + Jake_Cave_OF + Jake_Elmore_3B + Jake_Elmore_OF
#  + Jake_Faria_P + Jake_Hager_1B + Jake_Hager_2B + Jake_Irvin_P + Jake_Lamb_1B
#  + Jake_Marisnick_OF + Jake_McGee_P + Jake_Meyers_OF + Jake_Newberry_P
#  + Jake_Noll_2B + Jake_Odorizzi_P + Jake_Rogers_C + Jakob_Junis_P
#  + Jakson_Reetz_C + Jalen_Beeks_P + James_Bourque_P + James_Karinchak_P
#  + James_Marvel_P + James_McCann_C + James_Norwood_P + James_Paxton_P
#  + James_Pazos_P + James_Sherfy_P + Jameson_Taillon_P + Jamie_Ritchie_C
#  + Jandel_Gustave_P + Jared_Hughes_P + Jared_Oliva_OF + Jared_Shuster_P
#  + Jarlin_Garcia_P + Jarrett_Parker_OF + Jarrod_Dyson_OF + Jason_Adam_P
#  + Jason_Heyward_OF + Jason_Kipnis_2B + Jason_Martin_OF + Jasseel_De_La_Cruz_P
#  + Javier_Baez_SS + Javy_Guerra_P + Jay_Bruce_OF + Jaylin_Davis_OF
#  + Jean_Carlos_Mejia_P + Jean_Segura_2B + Jean_Segura_3B + Jed_Lowrie_2B
#  + Jedd_Gyorko_1B + Jedd_Gyorko_3B + Jeff_Hoffman_P + Jeff_Mathis_C
#  + Jeff_McNeil_2B + Jeff_McNeil_OF + Jeff_Samardzija_P + Jeffrey_Springs_P
#  + Jefry_Rodriguez_P + Jeimer_Candelario_1B + Jeison_Guzman_SS
#  + Jeremy_Beasley_P + Jeremy_Jeffress_P + Jeremy_Walker_P + Jesse_Chavez_P
#  + Jesse_Hahn_P + Jeurys_Familia_P + Jharel_Cotton_P + Jhoan_Duran_P
#  + Jhoulys_Chacin_P + Ji_Hwan_Bae_2B + Ji_Hwan_Bae_SS + Ji_Man_Choi_1B
#  + Jimmy_Cordero_P + Jimmy_Herget_P + Jimmy_Lambert_P + Jimmy_Nelson_P
#  + JoJo_Romero_P + Joan_Adon_P + Joc_Pederson_OF + Joe_Biagini_P
#  + Joe_Harvey_P + Joe_Jimenez_P + Joe_Kelly_P + Joe_Mantiply_P
#  + Joe_McCarthy_OF + Joe_Musgrove_P + Joe_Palumbo_P + Joe_Ryan_P
#  + Joel_Payamps_P + Joely_Rodriguez_P + Joey_Bart_C + Joey_Cantillo_P
#  + Joey_Gallo_OF + Joey_Rickard_OF + Joey_Wendle_2B + Johan_Camargo_2B
#  + John_Curtiss_P + John_Hicks_1B + John_Hicks_C + John_Means_P
#  + John_Ryan_Murphy_C + John_Schreiber_P + Johneshwy_Fargas_OF
#  + Johnny_Cueto_P + Jojanse_Torres_P + Jon_Duplantier_P + Jon_Gray_P
#  + Jon_Jay_OF + Jon_Lester_P + Jonathan_Arauz_2B + Jonathan_Arauz_3B
#  + Jonathan_Hernandez_P + Jonathan_Holder_P + Jonathan_Loaisiga_P
#  + Jonathan_Lucroy_C + Jonathan_Morales_C + Jonathan_Schoop_2B
# ...
# 0 <= Mason_Martin_OF <= 1 Integer
# 0 <= Mason_Williams_OF <= 1 Integer
# 0 <= Matt_Barnes_P <= 1 Integer
# 0 <= Matt_Beaty_1B <= 1 Integer
# 0 <= Matt_Blackham_P <= 1 Integer
# 0 <= Matt_Cronin_P <= 1 Integer
# 0 <= Matt_Duffy_3B <= 1 Integer
# 0 <= Matt_Duffy_SS <= 1 Integer
# 0 <= Matt_Foster_P <= 1 Integer
# 0 <= Matt_Grace_P <= 1 Integer
# 0 <= Matt_Hall_P <= 1 Integer
# 0 <= Matt_Harvey_P <= 1 Integer
# 0 <= Matt_Kemp_OF <= 1 Integer
# 0 <= Matt_Manning_P <= 1 Integer
# 0 <= Matt_Reynolds_2B <= 1 Integer
# 0 <= Matt_Reynolds_3B <= 1 Integer
# 0 <= Matt_Wisler_P <= 1 Integer
# 0 <= Matthew_Boyd_P <= 1 Integer
# 0 <= Mauricio_Dubon_OF <= 1 Integer
# 0 <= Mauricio_Dubon_SS <= 1 Integer
# 0 <= Mauricio_Llovera_P <= 1 Integer
# 0 <= Max_Fried_P <= 1 Integer
# 0 <= Max_Kepler_OF <= 1 Integer
# 0 <= Max_Kranick_P <= 1 Integer
# 0 <= Max_McDowell_C <= 1 Integer
# 0 <= Max_Moroff_2B <= 1 Integer
# 0 <= Max_Moroff_SS <= 1 Integer
# 0 <= Max_Muncy_1B <= 1 Integer
# 0 <= Max_Muncy_3B <= 1 Integer
# 0 <= Max_Scherzer_P <= 1 Integer
# 0 <= Meibrys_Viloria_C <= 1 Integer
# 0 <= Melky_Cabrera_OF <= 1 Integer
# 0 <= Melvin_Adon_P <= 1 Integer
# 0 <= Merrill_Kelly_P <= 1 Integer
# 0 <= Michael_A._Taylor_OF <= 1 Integer
# 0 <= Michael_Baumann_P <= 1 Integer
# 0 <= Michael_Brantley_OF <= 1 Integer
# 0 <= Michael_Busch_2B <= 1 Integer
# 0 <= Michael_Chavis_1B <= 1 Integer
# 0 <= Michael_Chavis_2B <= 1 Integer
# 0 <= Michael_Conforto_OF <= 1 Integer
# 0 <= Michael_Feliz_P <= 1 Integer
# 0 <= Michael_Fulmer_P <= 1 Integer
# 0 <= Michael_Grove_P <= 1 Integer
# 0 <= Michael_King_P <= 1 Integer
# 0 <= Michael_Papierski_C <= 1 Integer
# 0 <= Michael_Perez_C <= 1 Integer
# 0 <= Michael_Pineda_P <= 1 Integer
# 0 <= Michael_Wacha_P <= 1 Integer
# 0 <= Micker_Adolfo_OF <= 1 Integer
# 0 <= Miguel_Amaya_C <= 1 Integer
# 0 <= Miguel_Andujar_3B <= 1 Integer
# 0 <= Miguel_Andujar_OF <= 1 Integer
# 0 <= Miguel_Cabrera_1B <= 1 Integer
# 0 <= Miguel_Castro_P <= 1 Integer
# 0 <= Miguel_Del_Pozo_P <= 1 Integer
# 0 <= Miguel_Sano_1B <= 1 Integer
# 0 <= Miguel_Yajure_P <= 1 Integer
# 0 <= Mike_Brosseau_1B <= 1 Integer
# 0 <= Mike_Brosseau_2B <= 1 Integer
# 0 <= Mike_Foltynewicz_P <= 1 Integer
# 0 <= Mike_Ford_1B <= 1 Integer
# 0 <= Mike_Freeman_2B <= 1 Integer
# 0 <= Mike_Freeman_OF <= 1 Integer
# 0 <= Mike_Montgomery_P <= 1 Integer
# 0 <= Mike_Shawaryn_P <= 1 Integer
# 0 <= Mike_Soroka_P <= 1 Integer
# 0 <= Mike_Tauchman_OF <= 1 Integer
# 0 <= Mike_Yastrzemski_OF <= 1 Integer
# 0 <= Mike_Zunino_C <= 1 Integer
# 0 <= Mikie_Mahtook_OF <= 1 Integer
# 0 <= Mitch_Garver_C <= 1 Integer
# 0 <= Mitch_Keller_P <= 1 Integer
# 0 <= Mitch_White_P <= 1 Integer
# 0 <= Mookie_Betts_OF <= 1 Integer
# 0 <= Myles_Straw_OF <= 1 Integer
# 0 <= Nate_Lowe_1B <= 1 Integer
# 0 <= Nate_Lowe_3B <= 1 Integer
# 0 <= Nathan_Eovaldi_P <= 1 Integer
# 0 <= Neil_Walker_1B <= 1 Integer
# 0 <= Neil_Walker_2B <= 1 Integer
# 0 <= Nelson_Cruz_OF <= 1 Integer
# 0 <= Nick_Ahmed_SS <= 1 Integer
# 0 <= Nick_Anderson_P <= 1 Integer
# 0 <= Nick_Burdi_P <= 1 Integer
# 0 <= Nick_Ciuffo_C <= 1 Integer
# 0 <= Nick_Dini_C <= 1 Integer
# 0 <= Nick_Goody_P <= 1 Integer
# 0 <= Nick_Gordon_2B <= 1 Integer
# 0 <= Nick_Heath_OF <= 1 Integer
# 0 <= Nick_Madrigal_2B <= 1 Integer
# 0 <= Nick_Markakis_OF <= 1 Integer
# 0 <= Nick_Martini_OF <= 1 Integer
# 0 <= Nick_Mears_P <= 1 Integer
# 0 <= Nick_Nelson_P <= 1 Integer
# 0 <= Nick_Pratto_1B <= 1 Integer
# 0 <= Nick_Ramirez_P <= 1 Integer
# 0 <= Nick_Sandlin_P <= 1 Integer
# 0 <= Nick_Solak_2B <= 1 Integer
# 0 <= Nick_Solak_OF <= 1 Integer
# 0 <= Nick_Tanielu_2B <= 1 Integer
# 0 <= Nick_Tanielu_3B <= 1 Integer
# 0 <= Nick_Tropeano_P <= 1 Integer
# 0 <= Nick_Wells_P <= 1 Integer
# 0 <= Nick_Wittgren_P <= 1 Integer
# 0 <= Nicky_Delmonico_OF <= 1 Integer
# 0 <= Nicky_Lopez_2B <= 1 Integer
# 0 <= Nico_Hoerner_2B <= 1 Integer
# 0 <= Nico_Hoerner_3B <= 1 Integer
# 0 <= Nik_Turley_P <= 1 Integer
# 0 <= Niko_Goodrum_SS <= 1 Integer
# 0 <= Nivaldo_Rodriguez_P <= 1 Integer
# 0 <= Noah_Syndergaard_P <= 1 Integer
# 0 <= Nolan_Arenado_3B <= 1 Integer
# 0 <= Nolan_Blackwood_P <= 1 Integer
# 0 <= Nolan_Jones_3B <= 1 Integer
# 0 <= Nomar_Mazara_OF <= 1 Integer
# 0 <= Oliver_Drake_P <= 1 Integer
# 0 <= Oliver_Perez_P <= 1 Integer
# 0 <= Omar_Estevez_2B <= 1 Integer
# 0 <= Omar_Estevez_SS <= 1 Integer
# 0 <= Omar_Narvaez_C <= 1 Integer
# 0 <= Oneil_Cruz_SS <= 1 Integer
# 0 <= Orlando_Arcia_SS <= 1 Integer
# 0 <= Oscar_Hernandez_C <= 1 Integer
# 0 <= Oscar_Mercado_OF <= 1 Integer
# 0 <= Ozzie_Albies_2B <= 1 Integer
# 0 <= P.J._Higgins_C <= 1 Integer
# 0 <= Pablo_Sandoval_1B <= 1 Integer
# 0 <= Pat_Valaika_OF <= 1 Integer
# 0 <= Pat_Valaika_SS <= 1 Integer
# 0 <= Patrick_Corbin_P <= 1 Integer
# 0 <= Patrick_Mazeika_C <= 1 Integer
# 0 <= Patrick_Weigel_P <= 1 Integer
# 0 <= Paul_Fry_P <= 1 Integer
# 0 <= Paul_Sewald_P <= 1 Integer
# 0 <= Pavin_Smith_1B <= 1 Integer
# 0 <= Pedro_Baez_P <= 1 Integer
# 0 <= Pedro_Severino_C <= 1 Integer
# 0 <= Pete_Alonso_1B <= 1 Integer
# 0 <= Pete_Fairbanks_P <= 1 Integer
# 0 <= Peter_Lambert_P <= 1 Integer
# 0 <= Phil_Bickford_P <= 1 Integer
# 0 <= Phil_Gosselin_2B <= 1 Integer
# 0 <= Phil_Gosselin_OF <= 1 Integer
# 0 <= Phil_Maton_P <= 1 Integer
# 0 <= Philip_Pfeifer_P <= 1 Integer
# 0 <= Phillip_Diehl_P <= 1 Integer
# 0 <= Phillip_Evans_3B <= 1 Integer
# 0 <= Phillip_Evans_OF <= 1 Integer
# 0 <= Phillips_Valdez_P <= 1 Integer
# 0 <= Rafael_Devers_3B <= 1 Integer
# 0 <= Rafael_Marchan_C <= 1 Integer
# 0 <= Rafael_Montero_P <= 1 Integer
# 0 <= Raimel_Tapia_OF <= 1 Integer
# 0 <= Ralph_Garza_Jr._P <= 1 Integer
# 0 <= Ramon_Rosso_P <= 1 Integer
# 0 <= Ramon_Urias_2B <= 1 Integer
# 0 <= Randy_Arozarena_OF <= 1 Integer
# 0 <= Randy_Dobnak_P <= 1 Integer
# 0 <= Randy_Rosario_P <= 1 Integer
# 0 <= Ranger_Suarez_P <= 1 Integer
# 0 <= Raudy_Read_C <= 1 Integer
# 0 <= Ray_Black_P <= 1 Integer
# 0 <= Reggie_McClain_P <= 1 Integer
# 0 <= Renato_Nunez_1B <= 1 Integer
# 0 <= Rene_Rivera_C <= 1 Integer
# 0 <= Rex_Brothers_P <= 1 Integer
# 0 <= Reyes_Moronta_P <= 1 Integer
# 0 <= Reynaldo_Lopez_P <= 1 Integer
# 0 <= Rhys_Hoskins_1B <= 1 Integer
# 0 <= Rich_Hill_P <= 1 Integer
# 0 <= Richard_Lovelady_P <= 1 Integer
# 0 <= Richard_Rodriguez_P <= 1 Integer
# 0 <= Richie_Martin_SS <= 1 Integer
# 0 <= Rick_Porcello_P <= 1 Integer
# 0 <= Rico_Garcia_P <= 1 Integer
# 0 <= Riley_Greene_OF <= 1 Integer
# 0 <= Riley_Smith_P <= 1 Integer
# 0 <= Rio_Ruiz_3B <= 1 Integer
# 0 <= Rob_Refsnyder_1B <= 1 Integer
# 0 <= Rob_Refsnyder_OF <= 1 Integer
# 0 <= Robbie_Erlin_P <= 1 Integer
# 0 <= Robert_Gsellman_P <= 1 Integer
# 0 <= Robert_Stock_P <= 1 Integer
# 0 <= Roberto_Osuna_P <= 1 Integer
# 0 <= Roberto_Perez_C <= 1 Integer
# 0 <= Robinson_Cano_2B <= 1 Integer
# 0 <= Robinson_Chirinos_C <= 1 Integer
# 0 <= Robinson_Leyer_P <= 1 Integer
# 0 <= Rocky_Gale_C <= 1 Integer
# 0 <= Rodolfo_Castro_2B <= 1 Integer
# 0 <= Rodolfo_Castro_SS <= 1 Integer
# 0 <= Roenis_Elias_P <= 1 Integer
# 0 <= Rogelio_Armenteros_P <= 1 Integer
# 0 <= Roman_Quinn_OF <= 1 Integer
# 0 <= Ronald_Acuna_Jr._OF <= 1 Integer
# 0 <= Ronald_Bolanos_P <= 1 Integer
# 0 <= Ronald_Guzman_1B <= 1 Integer
# 0 <= Ronald_Torreyes_SS <= 1 Integer
# 0 <= Ronaldo_Hernandez_C <= 1 Integer
# 0 <= Ronnie_Dawson_OF <= 1 Integer
# 0 <= Ronny_Rodriguez_2B <= 1 Integer
# 0 <= Rony_Garcia_P <= 1 Integer
# 0 <= Rosell_Herrera_2B <= 1 Integer
# 0 <= Rosell_Herrera_OF <= 1 Integer
# 0 <= Ross_Detwiler_P <= 1 Integer
# 0 <= Rougned_Odor_2B <= 1 Integer
# 0 <= Rowan_Wick_P <= 1 Integer
# 0 <= Royce_Lewis_SS <= 1 Integer
# 0 <= Ryan_Brasier_P <= 1 Integer
# 0 <= Ryan_Braun_OF <= 1 Integer
# 0 <= Ryan_Burr_P <= 1 Integer
# 0 <= Ryan_Castellani_P <= 1 Integer
# 0 <= Ryan_Cordell_OF <= 1 Integer
# 0 <= Ryan_Garton_P <= 1 Integer
# 0 <= Ryan_Goins_3B <= 1 Integer
# 0 <= Ryan_Goins_OF <= 1 Integer
# 0 <= Ryan_Jeffers_C <= 1 Integer
# 0 <= Ryan_LaMarre_OF <= 1 Integer
# 0 <= Ryan_McBroom_1B <= 1 Integer
# 0 <= Ryan_McBroom_OF <= 1 Integer
# 0 <= Ryan_McKenna_OF <= 1 Integer
# 0 <= Ryan_McMahon_1B <= 1 Integer
# 0 <= Ryan_McMahon_2B <= 1 Integer
# 0 <= Ryan_Mountcastle_OF <= 1 Integer
# 0 <= Ryan_Pepiot_P <= 1 Integer
# 0 <= Ryan_Pressly_P <= 1 Integer
# 0 <= Ryan_Rolison_P <= 1 Integer
# 0 <= Ryan_Sherriff_P <= 1 Integer
# 0 <= Ryan_Tepera_P <= 1 Integer
# 0 <= Ryan_Thompson_P <= 1 Integer
# 0 <= Ryan_Weber_P <= 1 Integer
# 0 <= Ryan_Yarbrough_P <= 1 Integer
# 0 <= Ryley_Gilliam_P <= 1 Integer
# 0 <= Ryne_Harper_P <= 1 Integer
# 0 <= Ryon_Healy_1B <= 1 Integer
# 0 <= Ryon_Healy_3B <= 1 Integer
# 0 <= Salvador_Perez_C <= 1 Integer
# 0 <= Sam_Clay_P <= 1 Integer
# 0 <= Sam_Coonrod_P <= 1 Integer
# 0 <= Sam_Freeman_P <= 1 Integer
# 0 <= Sam_Hentges_P <= 1 Integer
# 0 <= Sam_Hilliard_OF <= 1 Integer
# 0 <= Sam_Howard_P <= 1 Integer
# 0 <= Sam_Huff_C <= 1 Integer
# 0 <= Sam_McWilliams_P <= 1 Integer
# 0 <= Sam_Selman_P <= 1 Integer
# 0 <= Sam_Wolff_P <= 1 Integer
# 0 <= Sandy_Leon_C <= 1 Integer
# 0 <= Scott_Alexander_P <= 1 Integer
# 0 <= Scott_Barlow_P <= 1 Integer
# 0 <= Scott_Blewett_P <= 1 Integer
# 0 <= Scott_Heineman_OF <= 1 Integer
# 0 <= Scott_Kingery_2B <= 1 Integer
# 0 <= Scott_Kingery_OF <= 1 Integer
# 0 <= Scott_Moss_P <= 1 Integer
# 0 <= Scott_Oberg_P <= 1 Integer
# 0 <= Sean_Doolittle_P <= 1 Integer
# 0 <= Sean_Gilmartin_P <= 1 Integer
# 0 <= Sean_Newcomb_P <= 1 Integer
# 0 <= Sean_Poppen_P <= 1 Integer
# 0 <= Sebastian_Rivero_C <= 1 Integer
# 0 <= Seby_Zavala_C <= 1 Integer
# 0 <= Seranthony_Dominguez_P <= 1 Integer
# 0 <= Sergio_Alcantara_SS <= 1 Integer
# 0 <= Sergio_Romo_P <= 1 Integer
# 0 <= Seth_Beer_OF <= 1 Integer
# 0 <= Seth_Lugo_P <= 1 Integer
# 0 <= Seth_Romero_P <= 1 Integer
# 0 <= Seuly_Matias_OF <= 1 Integer
# 0 <= Shane_Bieber_P <= 1 Integer
# 0 <= Shane_Greene_P <= 1 Integer
# 0 <= Shane_McClanahan_P <= 1 Integer
# 0 <= Shao_Ching_Chiang_P <= 1 Integer
# 0 <= Shaun_Anderson_P <= 1 Integer
# 0 <= Shawn_Armstrong_P <= 1 Integer
# 0 <= Shawn_Dubin_P <= 1 Integer
# 0 <= Shea_Langeliers_C <= 1 Integer
# 0 <= Shelby_Miller_P <= 1 Integer
# 0 <= Sherten_Apostel_3B <= 1 Integer
# 0 <= Shin_Soo_Choo_OF <= 1 Integer
# 0 <= Silvino_Bracho_P <= 1 Integer
# 0 <= Socrates_Brito_OF <= 1 Integer
# 0 <= Spencer_Howard_P <= 1 Integer
# 0 <= Spencer_Torkelson_3B <= 1 Integer
# 0 <= Spencer_Turnbull_P <= 1 Integer
# 0 <= Starlin_Castro_2B <= 1 Integer
# 0 <= Stefan_Crichton_P <= 1 Integer
# 0 <= Stephen_Strasburg_P <= 1 Integer
# 0 <= Stephen_Vogt_C <= 1 Integer
# 0 <= Stephen_Woods_Jr._P <= 1 Integer
# 0 <= Steve_Cishek_P <= 1 Integer
# 0 <= Steven_Baron_C <= 1 Integer
# 0 <= Steven_Brault_P <= 1 Integer
# 0 <= Steven_Duggar_OF <= 1 Integer
# 0 <= Steven_Fuentes_P <= 1 Integer
# 0 <= Steven_Matz_P <= 1 Integer
# 0 <= Steven_Souza_Jr._OF <= 1 Integer
# 0 <= Stevie_Wilkerson_2B <= 1 Integer
# 0 <= Stevie_Wilkerson_OF <= 1 Integer
# 0 <= Tanner_Rainey_P <= 1 Integer
# 0 <= Tanner_Scott_P <= 1 Integer
# 0 <= Tarik_Skubal_P <= 1 Integer
# 0 <= Taylor_Clarke_P <= 1 Integer
# 0 <= Taylor_Davis_C <= 1 Integer
# 0 <= Taylor_Hearn_P <= 1 Integer
# 0 <= Taylor_Jones_1B <= 1 Integer
# 0 <= Taylor_Rogers_P <= 1 Integer
# 0 <= Taylor_Walls_SS <= 1 Integer
# 0 <= Taylor_Widener_P <= 1 Integer
# 0 <= Tayron_Guerrero_P <= 1 Integer
# 0 <= Thairo_Estrada_2B <= 1 Integer
# 0 <= Thairo_Estrada_SS <= 1 Integer
# 0 <= Thomas_Dillard_1B <= 1 Integer
# 0 <= Thomas_Dillard_OF <= 1 Integer
# 0 <= Thomas_Szapucki_P <= 1 Integer
# 0 <= Tim_Anderson_SS <= 1 Integer
# 0 <= Tim_Cate_P <= 1 Integer
# 0 <= Tim_Collins_P <= 1 Integer
# 0 <= Tim_Federowicz_C <= 1 Integer
# 0 <= Tim_Locastro_OF <= 1 Integer
# 0 <= Todd_Frazier_3B <= 1 Integer
# 0 <= Tom_Eshelman_P <= 1 Integer
# 0 <= Tomas_Nido_C <= 1 Integer
# 0 <= Tomas_Telis_1B <= 1 Integer
# 0 <= Tommy_Henry_P <= 1 Integer
# 0 <= Tommy_Hunter_P <= 1 Integer
# 0 <= Tommy_Kahnle_P <= 1 Integer
# 0 <= Tommy_Milone_P <= 1 Integer
# 0 <= Tony_Gonsolin_P <= 1 Integer
# 0 <= Tony_Watson_P <= 1 Integer
# 0 <= Tony_Wolters_C <= 1 Integer
# 0 <= Touki_Toussaint_P <= 1 Integer
# 0 <= Travis_Blankenhorn_2B <= 1 Integer
# 0 <= Travis_Demeritte_OF <= 1 Integer
# 0 <= Travis_Lakins_P <= 1 Integer
# 0 <= Travis_Swaggerty_OF <= 1 Integer
# 0 <= Trea_Turner_SS <= 1 Integer
# 0 <= Tres_Barrera_C <= 1 Integer
# 0 <= Trevor_Cahill_P <= 1 Integer
# 0 <= Trevor_Gott_P <= 1 Integer
# 0 <= Trevor_Kelley_P <= 1 Integer
# 0 <= Trevor_Larnach_OF <= 1 Integer
# 0 <= Trevor_May_P <= 1 Integer
# 0 <= Trevor_Megill_P <= 1 Integer
# 0 <= Trevor_Oaks_P <= 1 Integer
# 0 <= Trevor_Richards_P <= 1 Integer
# 0 <= Trevor_Story_SS <= 1 Integer
# 0 <= Trevor_Williams_P <= 1 Integer
# 0 <= Trey_Mancini_1B <= 1 Integer
# 0 <= Trey_Mancini_OF <= 1 Integer
# 0 <= Trey_Supak_P <= 1 Integer
# 0 <= Tristen_Lutz_OF <= 1 Integer
# 0 <= Triston_McKenzie_P <= 1 Integer
# 0 <= Troy_Stokes_Jr._OF <= 1 Integer
# 0 <= Tucker_Davidson_P <= 1 Integer
# 0 <= Ty_Blach_P <= 1 Integer
# 0 <= Tyler_Alexander_P <= 1 Integer
# 0 <= Tyler_Anderson_P <= 1 Integer
# 0 <= Tyler_Bashlor_P <= 1 Integer
# 0 <= Tyler_Beede_P <= 1 Integer
# 0 <= Tyler_Chatwood_P <= 1 Integer
# 0 <= Tyler_Clippard_P <= 1 Integer
# 0 <= Tyler_Cyr_P <= 1 Integer
# 0 <= Tyler_Duffey_P <= 1 Integer
# 0 <= Tyler_Flowers_C <= 1 Integer
# 0 <= Tyler_Freeman_SS <= 1 Integer
# 0 <= Tyler_Glasnow_P <= 1 Integer
# 0 <= Tyler_Heineman_C <= 1 Integer
# 0 <= Tyler_Johnson_P <= 1 Integer
# 0 <= Tyler_Kinley_P <= 1 Integer
# 0 <= Tyler_Lyons_P <= 1 Integer
# 0 <= Tyler_Matzek_P <= 1 Integer
# 0 <= Tyler_Naquin_OF <= 1 Integer
# 0 <= Tyler_Nevin_1B <= 1 Integer
# 0 <= Tyler_Nevin_3B <= 1 Integer
# 0 <= Tyler_Phillips_P <= 1 Integer
# 0 <= Tyler_Rogers_P <= 1 Integer
# 0 <= Tyler_Wade_2B <= 1 Integer
# 0 <= Tyler_Wade_SS <= 1 Integer
# 0 <= Tyler_Zuber_P <= 1 Integer
# 0 <= Tyrone_Taylor_OF <= 1 Integer
# 0 <= Tyson_Miller_P <= 1 Integer
# 0 <= Tzu_Wei_Lin_OF <= 1 Integer
# 0 <= Tzu_Wei_Lin_SS <= 1 Integer
# 0 <= Victor_Arano_P <= 1 Integer
# 0 <= Victor_Caratini_C <= 1 Integer
# 0 <= Victor_Gonzalez_P <= 1 Integer
# 0 <= Victor_Reyes_OF <= 1 Integer
# 0 <= Victor_Robles_OF <= 1 Integer
# 0 <= Vidal_Brujan_2B <= 1 Integer
# 0 <= Vince_Velasquez_P <= 1 Integer
# 0 <= Wade_Davis_P <= 1 Integer
# 0 <= Wade_LeBlanc_P <= 1 Integer
# 0 <= Walker_Buehler_P <= 1 Integer
# 0 <= Walker_Lockett_P <= 1 Integer
# 0 <= Wander_Franco_SS <= 1 Integer
# 0 <= Wander_Suero_P <= 1 Integer
# 0 <= Wandy_Peralta_P <= 1 Integer
# 0 <= Wei_Chieh_Huang_P <= 1 Integer
# 0 <= Wes_Benjamin_P <= 1 Integer
# 0 <= Whit_Merrifield_OF <= 1 Integer
# 0 <= Wil_Crowe_P <= 1 Integer
# 0 <= Wilfredo_Tovar_SS <= 1 Integer
# 0 <= Will_Craig_1B <= 1 Integer
# 0 <= Will_Harris_P <= 1 Integer
# 0 <= Will_Smith_C <= 1 Integer
# 0 <= Will_Smith_P <= 1 Integer
# 0 <= Will_Wilson_SS <= 1 Integer
# 0 <= Willi_Castro_3B <= 1 Integer
# 0 <= Willi_Castro_SS <= 1 Integer
# 0 <= William_Contreras_C <= 1 Integer
# 0 <= Willians_Astudillo_3B <= 1 Integer
# 0 <= Willians_Astudillo_C <= 1 Integer
# 0 <= Willie_Calhoun_OF <= 1 Integer
# 0 <= Willson_Contreras_C <= 1 Integer
# 0 <= Willy_Adames_SS <= 1 Integer
# 0 <= Wilmer_Difo_2B <= 1 Integer
# 0 <= Wilmer_Difo_SS <= 1 Integer
# 0 <= Wilmer_Flores_1B <= 1 Integer
# 0 <= Wilmer_Flores_2B <= 1 Integer
# 0 <= Wilson_Ramos_C <= 1 Integer
# 0 <= Wyatt_Mathisen_2B <= 1 Integer
# 0 <= Wyatt_Mathisen_3B <= 1 Integer
# 0 <= Xander_Bogaerts_SS <= 1 Integer
# 0 <= Yacksel_Rios_P <= 1 Integer
# 0 <= Yadiel_Hernandez_OF <= 1 Integer
# 0 <= Yadiel_Rivera_2B <= 1 Integer
# 0 <= Yadiel_Rivera_OF <= 1 Integer
# 0 <= Yairo_Munoz_OF <= 1 Integer
# 0 <= Yairo_Munoz_SS <= 1 Integer
# 0 <= Yan_Gomes_C <= 1 Integer
# 0 <= Yandy_Diaz_3B <= 1 Integer
# 0 <= Yangervis_Solarte_2B <= 1 Integer
# 0 <= Yangervis_Solarte_OF <= 1 Integer
# 0 <= Yasmani_Grandal_C <= 1 Integer
# 0 <= Yency_Almonte_P <= 1 Integer
# 0 <= Yermin_Mercedes_C <= 1 Integer
# 0 <= Yoan_Aybar_P <= 1 Integer
# 0 <= Yoan_Lopez_P <= 1 Integer
# 0 <= Yoan_Moncada_3B <= 1 Integer
# 0 <= Yoenis_Cespedes_OF <= 1 Integer
# 0 <= Yohander_Mendez_P <= 1 Integer
# 0 <= Yolmer_Sanchez_2B <= 1 Integer
# 0 <= Yonathan_Daza_OF <= 1 Integer
# 0 <= Yonder_Alonso_1B <= 1 Integer
# 0 <= Yonny_Chirinos_P <= 1 Integer
# 0 <= Yordan_Alvarez_OF <= 1 Integer
# 0 <= Yoshi_Tsutsugo_3B <= 1 Integer
# 0 <= Yoshi_Tsutsugo_OF <= 1 Integer
# 0 <= Yu_Chang_3B <= 1 Integer
# 0 <= Yu_Darvish_P <= 1 Integer
# 0 <= Yuli_Gurriel_1B <= 1 Integer
# 0 <= Zac_Gallen_P <= 1 Integer
# 0 <= Zach_Eflin_P <= 1 Integer
# 0 <= Zach_Green_3B <= 1 Integer
# 0 <= Zach_McKinstry_SS <= 1 Integer
# 0 <= Zach_Plesac_P <= 1 Integer
# 0 <= Zach_Reks_OF <= 1 Integer
# 0 <= Zack_Britton_P <= 1 Integer
# 0 <= Zack_Brown_P <= 1 Integer
# 0 <= Zack_Burdi_P <= 1 Integer
# 0 <= Zack_Collins_C <= 1 Integer
# 0 <= Zack_Godley_P <= 1 Integer
# 0 <= Zack_Granite_OF <= 1 Integer
# 0 <= Zack_Greinke_P <= 1 Integer
# 0 <= Zack_Littell_P <= 1 Integer
# 0 <= Zack_Short_SS <= 1 Integer
# 0 <= Zack_Wheeler_P <= 1 Integer
# 0 <= Zander_Wiel_1B <= 1 Integer

# %%
# The problem is solved using PuLP's choice of Solver
prob.solve()
# Out:
# ---------------------------------------------------------------------------
# PulpSolverError                           Traceback (most recent call last)
# <ipython-input-61-8fb2da7171b6> in <module>()
#       1 # The problem is solved using PuLP's choice of Solver
# ----> 2 prob.solve()
#
# ~\Anaconda3\lib\site-packages\pulp\pulp.py in solve(self, solver, **kwargs)
#    1888         #time it
#    1889         self.solutionTime = -clock()
# -> 1890         status = solver.actualSolve(self, **kwargs)
#    1891         self.solutionTime += clock()
#    1892         self.restoreObjective(wasNone, dummyVar)
#
# ~\Anaconda3\lib\site-packages\pulp\apis\coin_api.py in actualSolve(self, lp, **kwargs)
#      99     def actualSolve(self, lp, **kwargs):
#     100         """Solve a well formulated lp problem"""
# --> 101         return self.solve_CBC(lp, **kwargs)
#     102
#     103     def available(self):
#
# ~\Anaconda3\lib\site-packages\pulp\apis\coin_api.py in solve_CBC(self, lp, use_mps)
#     157             pipe.close()
#     158         if not os.path.exists(tmpSol):
# --> 159             raise PulpSolverError("Pulp: Error while executing "+self.path)
#     160         status, values, reducedCosts, shadowPrices, slacks, sol_status = \
#     161             self.readsol_MPS(tmpSol, lp, vs, variablesNames, constraintsNames)
#
# PulpSolverError: Pulp: Error while executing C:\Users\prido\Anaconda3\lib\site-packages\pulp\apis\..\solverdir\cbc\win\64\cbc.exe

# %%
prob.status

# %%
print("Total Estimated Points = ", value(prob.objective))

# %%
# Each of the variables is printed with it's resolved optimum value
for v in prob.variables():
    if v.varValue == 1:
        print(v.name)
        v.getName
